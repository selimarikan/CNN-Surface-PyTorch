# %% [markdown]
# # Flower Classification

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# In this notebook, we are going to create a convolutional neural network (CNN) that can detect surface defects.
# Previously we have used Torch but now PyTorch will be used.
#
# PyTorch is the freshest flavour of the Torch. It combines customization of Torch with Python ease of use. It completely covers the Torch functionality, on top of that, new Autograd mechanism, dataset loaders and lots of utilities have been added for convenience.

# %% [markdown]
# ## 2. Code
#
# First, let's import required packages...

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file
from bokeh.palettes import Spectral7
from bokeh.io import output_notebook
from graphviz import Digraph
import numpy as np
import time
import copy
import os
import PIL
# %matplotlib inline
plt.ion()
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a66faa59-5f00-486b-aebd-f76d70b507e9">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## 2.1 Dataset transformations
# PyTorch lets us define a set of transformations to the loaded datasets.
#
# First images are converted to Torch tensors and then we will be scaling the images to 64 pixels in the smaller dimension.

# %%
baseDirectory = 'g:/Selim/Thesis/Code/PyTorch/'
setDirectory = 'Flower5Class'
setImageSize = 64

# Flower5Class mean and std
#Dim 0 mean: 0.462846264682
#Dim 0 stdv: 0.251614976903
#Dim 1 mean: 0.4218518616
#Dim 1 stdv: 0.22580325766
#Dim 2 mean: 0.300035001939
#Dim 2 stdv: 0.228333671604
setMean = [0.462, 0.421, 0.300]
setStd = [0.251, 0.225, 0.228]

# %%
dataTransforms = {
    'train': transforms.Compose([
        transforms.Scale(setImageSize),
        transforms.CenterCrop(setImageSize),
        transforms.ToTensor(),
        transforms.Normalize(mean=setMean, std=setStd)
    ]),
    'test': transforms.Compose([
        transforms.Scale(setImageSize),
        transforms.CenterCrop(setImageSize),
        transforms.ToTensor(),
        transforms.Normalize(mean=setMean, std=setStd)
    ]),
}

# %% [markdown]
# ## 2.2 Loading datasets
# Unlike Torch, PyTorch now supports direct image folder loading as the data. This completely removes the big dataset preparation step.
#
# Additionally new dataset loaders allow setting batch size, shuffle and several other useful parameters.
#
# Lastly checking the CUDA support is now easier with `torch.cuda.is_available()`

# %%
setPath = os.path.join(baseDirectory, setDirectory)
datasets = {x: torchvision.datasets.ImageFolder(os.path.join(setPath, x), dataTransforms[x])
           for x in ['train', 'test']}

datasetLoaders = {x: torch.utils.data.DataLoader(datasets[x], batch_size=4, shuffle=True, num_workers=4)
                for x in ['train', 'test']}

testLoader = torch.utils.data.DataLoader(datasets['test'], batch_size=1, shuffle=False, num_workers=4)

datasetSizes = {x: len(datasets[x]) for x in ['train', 'test']}
datasetClasses = datasets['train'].classes

useGPU = torch.cuda.is_available()

print(str(datasetSizes) + ' images will be used.' )
print('GPU will ' + ('' if useGPU else 'not ') + 'be used.' )
# Out:
# {'train': 2770, 'test': 900} images will be used.
# GPU will be used.

# %% [markdown]
# ## 2.3 Auxiliary functions
#
# ### 2.3.1 ImShow
# Here we define the simple image displaying function and use the new dataset iterator to get one random batch to display it.

# %%
def ImShow(input, title=None):
    input = input.numpy().transpose((1, 2, 0))
    input = setStd * input + setMean
    plt.figure(figsize=(8,8))
    plt.imshow(input)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

inputs, classes = next(iter(datasetLoaders['train']))
out = torchvision.utils.make_grid(inputs)
ImShow(out, title=[datasetClasses[x] for x in classes])

# %% [markdown]
# ### 2.3.2 VisualizeModel
#
# This function helps displaying the predictions of the network.

# %%
def VisualizeModel(model, numImages=6):
    imagesSoFar = 0
    fig = plt.figure()
    
    for i, data in enumerate(datasetLoaders['test']):
        inputs, labels = data
        if useGPU:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)
        
        outputs = model(inputs)
        _, preds = torch.max(outputs.data, 1)
        
        for j in range(inputs.size()[0]):
            imagesSoFar += 1
            ax = plt.subplot(numImages // 2, 2, imagesSoFar)
            ax.axis('off')
            ax.set_title('Predicted: {}'.format(datasetClasses[labels.data[j]]))
            ImShow(inputs.cpu().data[j])
            
            if imagesSoFar == numImages:
                return

# %% [markdown]
# ## 2.4 Training functions
#
# This section contains functions used in training the network. First we should create the arrays to keep the error and learning rate changes.

# %%
trainLRValues = []
trainAccuracyTrain = []
trainAccuracyTest = []
trainErrorTrain = []
trainErrorTest = []

grads = {}
def save_grad(name):
    def hook(grad):
        grads[name] = grad
    return hook

# %% [markdown]
# ### 2.4.1 TrainModelMiniBatch
#
# Here we have 2 different training functions. First one uses mini batches and a separate learning-rate scheduler function for training.

# %%
def TrainModelMiniBatch(model, criterion, optimizer, lr_scheduler, trainAccuracyArray, testAccuracyArray, 
                        lrLogArray, trainErrorArray, testErrorArray, num_epochs=25):
    since = time.time()
    del trainAccuracyArray[:]
    del testAccuracyArray[:]
    del lrLogArray[:]
    del trainErrorArray[:]
    del testErrorArray[:]
    
    best_model = model
    best_acc = 0.0
    currentLr = 0        

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        
        # Each epoch has a training and validation phase
        for phase in ['train', 'test']:
            if phase == 'train':
                optimizer, currentLr = lr_scheduler(optimizer, epoch)
                model.train(True)  # Set model to training mode
            else:
                model.train(False)  # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for data in datasetLoaders[phase]:
                # get the inputs
                inputs, labels = data

                # wrap them in Variable
                if useGPU:
                    inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
                else:
                    inputs, labels = Variable(inputs), Variable(labels)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                # backward + optimize only if in training phase
                if phase == 'train':
                    loss.backward()
                    optimizer.step()

                # statistics
                running_loss += loss.data[0]
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / datasetSizes[phase]
            epoch_acc = running_corrects / datasetSizes[phase]
            
            if phase == 'train':
                trainErrorArray.append(epoch_loss)
                trainAccuracyArray.append(epoch_acc)
                lrLogArray.append(currentLr)

            if phase == 'test':
                testErrorArray.append(epoch_loss)
                testAccuracyArray.append(epoch_acc)
            

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'test' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model = copy.deepcopy(model)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))
    return best_model

# %% [markdown]
# ### 2.4.2 TrainModelBatch
#
# This is the previous method of training which uses all of the images in the training set for each training iteration.

# %%
def TrainModelBatch(model, criterion, optimizer, lrDecay, trainAccuracyArray, 
                    lrLogArray, trainErrorArray, maxIteration):
    currentIteration = 0
    del trainAccuracyArray[:]
    del lrLogArray[:]
    del trainErrorArray[:]
    # TODO: Log the learning rate somehow!
    #currentLr = 0 
    
    startTime = time.time()
    trainSetSize = datasetSizes['train']
    
    shuffledIndices = torch.randperm(trainSetSize)
    print('Started training...')
    
    while True:
        runningLoss = 0.0
        runningCorrects = 0
        for iInput, data in enumerate(datasetLoaders['train'], 0):
            inputs, labels = data
            if useGPU:
                inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
            else:
                inputs, labels = Variable(inputs), Variable(labels)
            
            optimizer.zero_grad()
            
            outputs = model(inputs)
            _, preds = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            #print(iInput)
            runningLoss += loss.data[0]
            runningCorrects += torch.sum(preds == labels.data)
            
        currentError = runningLoss / trainSetSize
        currentAccuracy = runningCorrects / trainSetSize
        
        trainErrorArray.append(currentError)
        trainAccuracyArray.append(currentAccuracy)
        print('Iteration: ' + str(currentIteration) + '# current error = ' + str(currentError))
        currentIteration += 1
        
        if maxIteration > 0 and currentIteration > maxIteration:
            print('# Maximum iteration reached. End of training.')
            print('# Training error = ' + str(currentError))
            timeElapsed = time.time() - startTime            
            print('Training complete in {:.0f}m {:.0f}s'.format(timeElapsed // 60, timeElapsed % 60))
            break

# %% [markdown]
# ### 2.4.3 ExpLRScheduler
#
# Updates the learning-rate after each `lr_decay_epoch` number of epochs.

# %%
def ExpLRScheduler(optimizer, epoch, init_lr=0.001, lr_decay_epoch=7):
    lr = init_lr * (0.1 ** (epoch // lr_decay_epoch))
    
    if epoch % lr_decay_epoch == 0:
        print('LR is set to {}'.format(lr))
        
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    
    return optimizer, lr

# %% [markdown]
# ## 2.5 Definition of neural network
#
# ### 2.5.1 Network module
# Similar to Torch, here we define the neural network using separate modules.
# First module handles the convolutional part of the network. After that a reshape operation adjust the convolution result for the following fully-connected layer module. Lastly, the result is applied to the fully-connected layer of the network and decisions are obtained with LogSoftMax operation in the end.

# %%
# Currently, weights are not shared.
# TODO: Try weight sharing with looping the element
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.convIn = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.reluIn = nn.ReLU()
        self.poolIn = nn.MaxPool2d(2, 2)
        
        self.convI2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.reluI2 = nn.ReLU()
        self.poolI2 = nn.MaxPool2d(2, 2)
        
        self.convI3 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.reluI3 = nn.ReLU()
        self.poolI3 = nn.MaxPool2d(2, 2)
        
        self.outMul = int(setImageSize / 8) 
            
        self.fc = nn.Sequential(
            nn.Linear(32 * self.outMul * self.outMul, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 5)) # number of classes
        
        self.logsmax = nn.LogSoftmax()

    def forward(self, x):
        # Convolutional layer 1
        convInResult = self.convIn(x)
        convInResult.register_hook(save_grad('convInGrad'))
        x = self.poolIn(self.reluIn(convInResult))
        
        # Convolutional layer 2
        convI2Result = self.convI2(x)
        convI2Result.register_hook(save_grad('convI2Grad'))
        x = self.poolI2(self.reluI2(convI2Result))
        
        # Convolutional layer 3
        convI3Result = self.convI3(x)
        convI3Result.register_hook(save_grad('convI3Grad'))
        x = self.poolI3(self.reluI3(convI3Result))
        
        
        # Reshape the result for fully-connected layers
        x = x.view(-1, 32 * self.outMul * self.outMul)
        
        # Apply the result to fully-connected layers
        x = self.fc(x)
        
        # Finally apply the LogSoftMax for output
        x = self.logsmax(x)
        return x

net = Net()
if useGPU:
    net = net.cuda()

# %% [markdown]
# ### 2.5.2 Criterion and optimizer
# We successfully created our neural network. Now it is time to define a loss function and the optimizer.

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

if useGPU:
    criterion = criterion.cuda()

# %% [markdown]
# ## 2.6 Training
#
# Mini-batch training method is preferred with PyTorch. It converges faster than the batch training method.
#
# *Example*
#
# *Mini-batch : With GTX 1070, 10 epochs train in 7m26s with 97.6% train and 97.6% test accuracy.*
#
# *Batch      : With GTX 1070, 10 epochs train in 7m48s with 98.4% train and 96.5% test accuracy.*

# %% [markdown]
# ### 2.6.1 Training with mini-batch method
# Mini-batch method first selects n items randomly from the dataset and runs one epoch on the selected subset. Weights are updated only by looking to the selected subset.

# %%
TrainModelMiniBatch(net, criterion, optimizer, ExpLRScheduler, trainAccuracyTrain, trainAccuracyTest, trainLRValues, 
                    trainErrorTrain, trainErrorTest, num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# LR is set to 0.001
# train Loss: 0.3984 Acc: 0.2617
# test Loss: 0.3913 Acc: 0.3711
#
# Epoch 1/4
# ----------
# train Loss: 0.3549 Acc: 0.3733
# test Loss: 0.3400 Acc: 0.3856
#
# Epoch 2/4
# ----------
# train Loss: 0.3411 Acc: 0.3819
# test Loss: 0.3299 Acc: 0.4156
#
# Epoch 3/4
# ----------
# train Loss: 0.3301 Acc: 0.4004
# test Loss: 0.3193 Acc: 0.4289
#
# Epoch 4/4
# ----------
# train Loss: 0.3210 Acc: 0.4343
# test Loss: 0.3105 Acc: 0.5200
#
# Training complete in 1m 49s
# Best val Acc: 0.520000
# Net (
#   (convIn): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (reluIn): ReLU ()
#   (poolIn): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (convI2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (reluI2): ReLU ()
#   (poolI2): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (convI3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (reluI3): ReLU ()
#   (poolI3): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (fc): Sequential (
#     (0): Linear (2048 -> 4096)
#     (1): ReLU ()
#     (2): Dropout (p = 0.5)
#     (3): Linear (4096 -> 4096)
#     (4): ReLU ()
#     (5): Dropout (p = 0.5)
#     (6): Linear (4096 -> 4096)
#     (7): ReLU ()
#     (8): Dropout (p = 0.5)
#     (9): Linear (4096 -> 5)
#   )
#   (logsmax): LogSoftmax ()
# )

# %% [markdown]
# ### 2.6.2 Training with batch method
# Batch method uses all of the images in the dataset to determine the gradient for each epoch.

# %%
TrainModelBatch(net, criterion, optimizer, 0, trainAccuracyTrain, trainLRValues, trainErrorTrain, maxIteration=5)
# Out:
# Started training...
# Iteration: 0# current error = 0.4005436058078862
# Iteration: 1# current error = 0.37738746312120763
# Iteration: 2# current error = 0.31122786258532253
# Iteration: 3# current error = 0.29327772728802926
# Iteration: 4# current error = 0.27062184814942014
# Iteration: 5# current error = 0.25247074881777004
# # Maximum iteration reached. End of training.
# # Training error = 0.25247074881777004
# Training complete in 1m 33s

# %%
def make_dot(var, params=None):
    """ Produces Graphviz representation of PyTorch autograd graph
    Blue nodes are the Variables that require grad, orange are Tensors
    saved for backward in torch.autograd.Function
    Args:
        var: output Variable
        params: dict of (name, Variable) to add names to node that
            require grad (TODO: make optional)
    """
    if params is not None:
        assert isinstance(params.values()[0], Variable)
        param_map = {id(v): k for k, v in params.items()}

    node_attr = dict(style='filled',
                     shape='box',
                     align='left',
                     fontsize='12',
                     ranksep='0.1',
                     height='0.2')
    dot = Digraph(node_attr=node_attr, graph_attr=dict(size="12,12"))
    seen = set()

    def size_to_str(size):
        return '('+(', ').join(['%d' % v for v in size])+')'

    def add_nodes(var):
        if var not in seen:
            if torch.is_tensor(var):
                dot.node(str(id(var)), size_to_str(var.size()), fillcolor='orange')
            elif hasattr(var, 'variable'):
                u = var.variable
                name = param_map[id(u)] if params is not None else ''
                node_name = '%s\n %s' % (name, size_to_str(u.size()))
                dot.node(str(id(var)), node_name, fillcolor='lightblue')
            else:
                dot.node(str(id(var)), str(type(var).__name__))
            seen.add(var)
            if hasattr(var, 'next_functions'):
                for u in var.next_functions:
                    if u[0] is not None:
                        dot.edge(str(id(u[0])), str(id(var)))
                        add_nodes(u[0])
            if hasattr(var, 'saved_tensors'):
                for t in var.saved_tensors:
                    dot.edge(str(id(t)), str(id(var)))
                    add_nodes(t)
    add_nodes(var.grad_fn)
    return dot

inputs = torch.randn(1,3,64,64)
y = net(Variable(inputs.cuda()))
make_dot(y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# g:\Anaconda3\envs\PyTorchEnv\lib\site-packages\graphviz\backend.py in pipe(engine, format, data, quiet)
#     152             stdout=subprocess.PIPE, stderr=subprocess.PIPE,
# --> 153             startupinfo=STARTUPINFO)
#     154     except OSError as e:
#
# g:\Anaconda3\envs\PyTorchEnv\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     706                                 errread, errwrite,
# --> 707                                 restore_signals, start_new_session)
#     708         except:
#
# g:\Anaconda3\envs\PyTorchEnv\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#     989                                          cwd,
# --> 990                                          startupinfo)
#     991             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# g:\Anaconda3\envs\PyTorchEnv\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     334             method = get_real_method(obj, self.print_method)
#     335             if method is not None:
# --> 336                 return method()
#     337             return None
#     338         else:
#
# g:\Anaconda3\envs\PyTorchEnv\lib\site-packages\graphviz\files.py in _repr_svg_(self)
#      99
#     100     def _repr_svg_(self):
# --> 101         return self.pipe(format='svg').decode(self._encoding)
#     102
#     103     def pipe(self, format=None):
#
# g:\Anaconda3\envs\PyTorchEnv\lib\site-packages\graphviz\files.py in pipe(self, format)
#     118         data = text_type(self.source).encode(self._encoding)
#     119
# --> 120         outs = backend.pipe(self._engine, format, data)
#     121
#     122         return outs
#
# g:\Anaconda3\envs\PyTorchEnv\lib\site-packages\graphviz\backend.py in pipe(engine, format, data, quiet)
#     154     except OSError as e:
#     155         if e.errno == errno.ENOENT:
# --> 156             raise ExecutableNotFound(args)
#     157         else:  # pragma: no cover
#     158             raise
#
# ExecutableNotFound: failed to execute ['dot', '-Tsvg'], make sure the Graphviz executables are on your systems' PATH

# %%
gradIn = grads['convInGrad']
gradI2 = grads['convI2Grad']
gradI3 = grads['convI3Grad']

def PlotActivationMaps(gradients):
    for iT in range(gradients.size()[0]):
        plt.figure(figsize=(8,8))
        for z in range(gradients.size()[1]):
            plt.subplot(4, 8, z+1)
            plt.title(str(iT) + str(z))
            plt.axis('off')
            
            plt.imshow(gradients[iT, z, :, :].data.cpu().numpy(), interpolation='nearest')
        
PlotActivationMaps(gradIn)
PlotActivationMaps(gradI2)
PlotActivationMaps(gradI3)

# %% [markdown]
# ### 2.6.3 Visualization of the progress

# %%
def PlotArrays(arrays, labels, xlabel, ylabel, title):
    p = figure(title=title, x_axis_label=xlabel, y_axis_label=ylabel)
    length = len(arrays[0])
    palette = Spectral7[0:len(arrays)]
    x = np.linspace(0, length - 1, length)
    i = 0
    
    for array, label in zip(arrays, labels):
        p.circle(x, array, legend=label, fill_color=palette[i], line_color=palette[i])
        p.line(x, array, legend=label, line_color=palette[i], line_width=2)
        i += 1
    
    p.legend.location = 'top_right'
    show(p)

PlotArrays([trainErrorTrain, trainErrorTest], ['Training', 'Test'], xlabel='Epoch', ylabel='Loss', title='Loss over epoch')
PlotArrays([trainLRValues], ['Learning rate'], xlabel='Epoch', ylabel='Learning rate', title='Learning rate decrease')
PlotArrays([trainAccuracyTrain, trainAccuracyTest], ['Training accuracy', 'Test accuracy'], xlabel='Epoch', ylabel='Accuracy', title='Accuracy increase over epoch')
# Out:
# g:\Anaconda3\envs\PyTorchEnv\lib\site-packages\bokeh\models\sources.py:91: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 6), ('y', 0)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# g:\Anaconda3\envs\PyTorchEnv\lib\site-packages\bokeh\models\sources.py:91: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 6), ('y', 0)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="78e9c9f8-b393-4da2-a0e2-c9522a297327"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("78e9c9f8-b393-4da2-a0e2-c9522a297327");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("78e9c9f8-b393-4da2-a0e2-c9522a297327");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '78e9c9f8-b393-4da2-a0e2-c9522a297327' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0bb208a6-4505-4083-b572-6dcfdc6f2ff3":{"roots":{"references":[{"attributes":{},"id":"9a5a1f6c-59c6-4edc-b214-62fa386cbf2b","type":"LinearScale"},{"attributes":{"axis_label":"Epoch","formatter":{"id":"0a88e74d-a571-4dc7-b3f1-0b2fbf179713","type":"BasicTickFormatter"},"plot":{"id":"0f893b6c-c1df-4cf3-9eac-33e674ec8e30","subtype":"Figure","type":"Plot"},"ticker":{"id":"4f252b85-30eb-43cf-ae9b-23d6171803c6","type":"BasicTicker"}},"id":"d9519a07-452c-4311-a7ce-40b03622717e","type":"LinearAxis"},{"attributes":{},"id":"47a26518-41ef-4b47-b9aa-3b35a8daa4db","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"0f893b6c-c1df-4cf3-9eac-33e674ec8e30","subtype":"Figure","type":"Plot"}},"id":"b389c1c8-c545-489b-8025-62084408e009","type":"HelpTool"},{"attributes":{"fill_color":{"value":"#3288bd"},"line_color":{"value":"#3288bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8f8c6c91-2a9d-46b6-b424-73f4017bc722","type":"Circle"},{"attributes":{"callback":null},"id":"425afc5f-fd9a-457c-98ac-a510461b1f04","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRA","dtype":"float64","shape":[6]},"y":[0.4005436058078862,0.37738746312120763,0.31122786258532253,0.29327772728802926,0.27062184814942014,0.25247074881777004]}},"id":"6cc0a434-043f-4be1-8bbc-bb633feb67e2","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"0f893b6c-c1df-4cf3-9eac-33e674ec8e30","subtype":"Figure","type":"Plot"}},"id":"118f5c3e-83fb-4057-94ef-1d9d2f1e72b4","type":"ResetTool"},{"attributes":{},"id":"6b674911-4eb9-4556-a6ec-db1e1ad9c821","type":"BasicTicker"},{"attributes":{},"id":"0a88e74d-a571-4dc7-b3f1-0b2fbf179713","type":"BasicTickFormatter"},{"attributes":{},"id":"5ef19353-cbdc-4f60-a486-b0629ab9c773","type":"ToolEvents"},{"attributes":{"data_source":{"id":"8fae970a-6f99-4363-837e-170b59080727","type":"ColumnDataSource"},"glyph":{"id":"8edbe91b-85b9-4a7c-89b4-67b0e1314135","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"747e06c5-68e1-4da9-a2ad-0dcc0d09b907","type":"Line"},"selection_glyph":null},"id":"fd46e457-8745-40c9-b964-6b9d8a28b0c2","type":"GlyphRenderer"},{"attributes":{},"id":"982f573f-1fe6-46e0-a5de-f646aa7f71eb","type":"LinearScale"},{"attributes":{"callback":null},"id":"248d858c-4318-45cf-9dd8-3ce2c0d7a169","type":"DataRange1d"},{"attributes":{"plot":{"id":"0f893b6c-c1df-4cf3-9eac-33e674ec8e30","subtype":"Figure","type":"Plot"},"ticker":{"id":"4f252b85-30eb-43cf-ae9b-23d6171803c6","type":"BasicTicker"}},"id":"86dc4d24-749a-42b3-ac72-b42fe3df448b","type":"Grid"},{"attributes":{"data_source":{"id":"6cc0a434-043f-4be1-8bbc-bb633feb67e2","type":"ColumnDataSource"},"glyph":{"id":"8f8c6c91-2a9d-46b6-b424-73f4017bc722","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a1a5b4ee-c7a4-435d-975e-f357c4070fa3","type":"Circle"},"selection_glyph":null},"id":"a703250a-99d9-4d5b-a584-a7b667077876","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dc6ea76c-bdc9-439d-a793-ba405d2c7643","type":"PanTool"},{"id":"4bca1e03-e3c0-4474-8b06-186a86bcf408","type":"WheelZoomTool"},{"id":"5b369420-be48-4c33-960c-bee19417d200","type":"BoxZoomTool"},{"id":"1e3ef80f-249c-4e2a-afa8-b6ae034d55c8","type":"SaveTool"},{"id":"118f5c3e-83fb-4057-94ef-1d9d2f1e72b4","type":"ResetTool"},{"id":"b389c1c8-c545-489b-8025-62084408e009","type":"HelpTool"}]},"id":"fd26e1aa-4816-4063-84fd-8547246e1292","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e434366e-d123-46ce-bedc-287fce4b7d83","type":"BoxAnnotation"},{"attr ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="494e982b-a5f4-4a3b-a3a5-5563a48ea046"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("494e982b-a5f4-4a3b-a3a5-5563a48ea046");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("494e982b-a5f4-4a3b-a3a5-5563a48ea046");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '494e982b-a5f4-4a3b-a3a5-5563a48ea046' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e1430ec1-63b6-4b5f-88b1-ab8e67927e50":{"roots":{"references":[{"attributes":{},"id":"da0102aa-58da-4bd6-877d-3b1ecd8d6f2d","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#3288bd"},"line_color":{"value":"#3288bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"99687e19-df3d-4cba-b48d-a6124c7d872a","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3bb1eb14-e65b-40d9-924b-15c8cdbe0d32","type":"Line"},{"attributes":{"callback":null},"id":"0d02c312-bbaa-4813-96e4-cb70e70a4ecf","type":"DataRange1d"},{"attributes":{"plot":{"id":"d8a29bcb-91d8-472d-813f-8aaf018852b6","subtype":"Figure","type":"Plot"}},"id":"dd1938ea-d0b4-463e-ab07-9b21a3515302","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"f4e1a802-1cb5-4b90-97e8-d1db201b39b0","type":"DataRange1d"},{"attributes":{},"id":"172fec5c-6d77-49d8-8477-c183cab13e6b","type":"LinearScale"},{"attributes":{"data_source":{"id":"870e29c1-a243-48e3-b38a-4aaacd844423","type":"ColumnDataSource"},"glyph":{"id":"30ca540a-6261-4ff6-981e-709aa4c74f1e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3bb1eb14-e65b-40d9-924b-15c8cdbe0d32","type":"Line"},"selection_glyph":null},"id":"70134337-df77-43d0-8f06-a04a6f9f82d0","type":"GlyphRenderer"},{"attributes":{"axis_label":"Epoch","formatter":{"id":"a5e9ff1a-2c54-4f03-b16a-ffcd7effad42","type":"BasicTickFormatter"},"plot":{"id":"d8a29bcb-91d8-472d-813f-8aaf018852b6","subtype":"Figure","type":"Plot"},"ticker":{"id":"da0102aa-58da-4bd6-877d-3b1ecd8d6f2d","type":"BasicTicker"}},"id":"cd4d8e0e-67c4-4c22-aac2-dd4f14e502ea","type":"LinearAxis"},{"attributes":{"plot":{"id":"d8a29bcb-91d8-472d-813f-8aaf018852b6","subtype":"Figure","type":"Plot"}},"id":"52b5eb7f-e242-497a-94f0-9a6781d157be","type":"HelpTool"},{"attributes":{},"id":"83cbac9b-fd98-4922-941a-8d465ba92f7e","type":"ToolEvents"},{"attributes":{},"id":"72d6ec29-c582-47a6-8132-da0f51de4c38","type":"LinearScale"},{"attributes":{"label":{"value":"Learning rate"},"renderers":[{"id":"c3490163-47be-4586-b464-fac57c78ea97","type":"GlyphRenderer"},{"id":"70134337-df77-43d0-8f06-a04a6f9f82d0","type":"GlyphRenderer"}]},"id":"1b1a2497-6a94-42ce-8ec3-5cee2c79b040","type":"LegendItem"},{"attributes":{},"id":"a5e9ff1a-2c54-4f03-b16a-ffcd7effad42","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Learning rate decrease"},"id":"f2c833be-dc22-4814-b086-227234ae75e5","type":"Title"},{"attributes":{},"id":"1130cf51-cb40-40fb-bd71-69a567883a6f","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Learning rate","formatter":{"id":"1130cf51-cb40-40fb-bd71-69a567883a6f","type":"BasicTickFormatter"},"plot":{"id":"d8a29bcb-91d8-472d-813f-8aaf018852b6","subtype":"Figure","type":"Plot"},"ticker":{"id":"b32c08a8-7b04-4e1a-a745-18d24a2df8ac","type":"BasicTicker"}},"id":"5764ef33-d126-4c02-9b85-f7b1c98b010f","type":"LinearAxis"},{"attributes":{"overlay":{"id":"25d04042-713c-4da0-9793-9c2cfa6cf090","type":"BoxAnnotation"},"plot":{"id":"d8a29bcb-91d8-472d-813f-8aaf018852b6","subtype":"Figure","type":"Plot"}},"id":"eece1c5d-91d0-44b7-b4af-9aa04c03ecda","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"#3288bd"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"30ca540a-6261-4ff6-981e-709aa4c74f1e","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"d8a29bcb-91d8-472d-813f-8aaf018852b6","subtype":"Figure","type":"Plot"},"ticker":{"id":"b32c08a8-7b04-4e1a-a745-18d24a2df8ac","type":"BasicTicker"}},"id":"90360cbe-49a6-461e-8d9c-9c626f1271d3","type":"Grid"},{"attributes":{"plot":{"id":"d8a29bcb-91d8-472d-813f-8aaf018852b6","subtype":"Figure","type":"Plot"}},"id":"8969d684-f3a2-4ece-a05d-cd127dd31238","type":"ResetTool"},{"attributes":{"below":[{"id":"cd4d8e0e-67c4-4c22-aac2-dd4f14e502ea","type":"LinearAxis"}],"left":[{"id":"5764ef33-d126-4c02-9b85-f7b1c98b010f","type":"LinearAxis"}],"renderers":[{"id ...
# g:\Anaconda3\envs\PyTorchEnv\lib\site-packages\bokeh\models\sources.py:91: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 6), ('y', 0)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# g:\Anaconda3\envs\PyTorchEnv\lib\site-packages\bokeh\models\sources.py:91: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 6), ('y', 0)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8ae91e5e-69aa-48bf-9fc4-a373ec39e7eb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8ae91e5e-69aa-48bf-9fc4-a373ec39e7eb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8ae91e5e-69aa-48bf-9fc4-a373ec39e7eb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8ae91e5e-69aa-48bf-9fc4-a373ec39e7eb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"69ddb089-33e2-4d18-b8de-78817c17c6f7":{"roots":{"references":[{"attributes":{},"id":"171e1f4d-aebe-4732-921c-c1f76e325a24","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRA","dtype":"float64","shape":[6]},"y":[]}},"id":"2594a7ab-6e33-4f34-9e24-9d57ac3fdac9","type":"ColumnDataSource"},{"attributes":{},"id":"531a21b5-c6aa-4ef8-b90c-94e55ba09adf","type":"ToolEvents"},{"attributes":{"data_source":{"id":"2594a7ab-6e33-4f34-9e24-9d57ac3fdac9","type":"ColumnDataSource"},"glyph":{"id":"b4aedc47-1d56-43ba-8a2e-7de0b4c118b6","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b04960dd-92d5-4325-923b-677a20d99c6d","type":"Line"},"selection_glyph":null},"id":"4883ef96-574e-43ed-b24c-aabbff22bf25","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"4c8acc30-63cc-402d-8382-7a64fbda3781","type":"LinearAxis"}],"left":[{"id":"459dd82b-e17c-4e05-928d-917c73809fc8","type":"LinearAxis"}],"renderers":[{"id":"4c8acc30-63cc-402d-8382-7a64fbda3781","type":"LinearAxis"},{"id":"f52014cf-755f-44da-8701-66c0787f24db","type":"Grid"},{"id":"459dd82b-e17c-4e05-928d-917c73809fc8","type":"LinearAxis"},{"id":"4c7ef0b7-2158-4285-88fc-6950cf2d3925","type":"Grid"},{"id":"90823f1f-c07a-4f8a-a270-876d3b26d75c","type":"BoxAnnotation"},{"id":"b83404c5-02d1-4b64-a195-364fc87cd8c8","type":"Legend"},{"id":"fe6dbdd4-428e-4101-b9ef-71bc29240f7d","type":"GlyphRenderer"},{"id":"d6c91d7f-ad17-4bbf-868c-a7c35aad53f4","type":"GlyphRenderer"},{"id":"e8a14ce0-3f01-429d-ba44-969a90058a2e","type":"GlyphRenderer"},{"id":"4883ef96-574e-43ed-b24c-aabbff22bf25","type":"GlyphRenderer"}],"title":{"id":"72ce9cee-f8f9-4059-b798-5a3dd244e3ec","type":"Title"},"tool_events":{"id":"531a21b5-c6aa-4ef8-b90c-94e55ba09adf","type":"ToolEvents"},"toolbar":{"id":"d7877a41-107c-474e-8beb-2c5c65056fed","type":"Toolbar"},"x_range":{"id":"5d26f2db-f060-460b-855d-c9a3f00c09bb","type":"DataRange1d"},"x_scale":{"id":"171e1f4d-aebe-4732-921c-c1f76e325a24","type":"LinearScale"},"y_range":{"id":"299e4fc1-ff1b-4208-bc73-83556598580a","type":"DataRange1d"},"y_scale":{"id":"ea4cf870-52c4-4945-b6ec-b6e848498b52","type":"LinearScale"}},"id":"16d88bf3-7a24-4d42-8669-7af196b04932","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"#99d594"},"line_color":{"value":"#99d594"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d24cc70b-1c26-4a40-b8aa-639800339901","type":"Circle"},{"attributes":{},"id":"dceae513-b4df-4097-9360-9a5006bc4ded","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Accuracy increase over epoch"},"id":"72ce9cee-f8f9-4059-b798-5a3dd244e3ec","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e0b39e89-6679-49e5-b2f1-e0bac527ea20","type":"Circle"},{"attributes":{"plot":{"id":"16d88bf3-7a24-4d42-8669-7af196b04932","subtype":"Figure","type":"Plot"},"ticker":{"id":"bd18d6a3-9961-4ef8-82dd-8d0b0e3959df","type":"BasicTicker"}},"id":"f52014cf-755f-44da-8701-66c0787f24db","type":"Grid"},{"attributes":{"fill_color":{"value":"#3288bd"},"line_color":{"value":"#3288bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9c39fbbf-45c4-47fb-af89-054e184c1862","type":"Circle"},{"attributes":{"axis_label":"Epoch","formatter":{"id":"d5b0ba8a-c0bd-4680-8911-72997dc56c4f","type":"BasicTickFormatter"},"plot":{"id":"16d88bf3-7a24-4d42-8669-7af196b04932","subtype":"Figure","type":"Plot"},"ticker":{"id":"bd18d6a3-9961-4ef8-82dd-8d0b0e3959df","type":"BasicTicker"}},"id":"4c8acc30-63cc-402d-8382-7a64fbda3781","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#99d594"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"b4aedc47-1d56-43ba-8a2e-7de0b4c118b6","type":"Line"},{"attributes":{"items":[{"id":"6a4f1e6e-e40c-4287-8574-07d567f02f8d","type":"LegendItem"},{"id":"f ...

# %% [markdown]
# ## 2.7 Visualization of the weights
#
# This section is still in development.

# %%
#VisualizeModel(net)

# %%
# IN PROGRESS...
def plot_kernels(tensor, num_cols=6):
    if not tensor.ndim==4:
        raise Exception("assumes a 4D tensor")
    if not tensor.shape[-1]==3:
        raise Exception("last dim needs to be 3 to plot")
    num_kernels = tensor.shape[0]
    num_rows = 1+ num_kernels // num_cols
    fig = plt.figure(figsize=(num_cols,num_rows))
    for i in range(tensor.shape[0]):
        ax1 = fig.add_subplot(num_rows,num_cols,i+1)
        ax1.imshow(tensor[i])
        ax1.axis('off')
        ax1.set_xticklabels([])
        ax1.set_yticklabels([])

    plt.subplots_adjust(wspace=0.1, hspace=0.1)
    plt.show()
#plot_kernels(net.conv[6].weight.cpu().data.numpy())

# %%
import math
def plotNNFilter(units):
    filters = units.shape[3]
    plt.figure(1, figsize=(20,20))
    n_columns = 6
    n_rows = math.ceil(filters / n_columns) + 1
    for i in range(filters):
        plt.subplot(n_rows, n_columns, i+1)
        plt.title('Filter ' + str(i))
        plt.imshow(units[0,:,:,i], interpolation="nearest", cmap="gray")

# %%
plotNNFilter(net.convI2.weight.cpu().data.numpy())

# %% [markdown]
# ## 2.8 Evaluating network accuracy
# Let's calculate the accuracy on the training set.

# %%
def DetermineAccuracy(phase):
    correct = 0
    total = 0
    for data in datasetLoaders[phase]:
        # Inputs
        inputs, labels = data
        if useGPU:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        outputs = net(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.data).sum()
    return correct, total

# %%
correct, total = DetermineAccuracy('train')
print('Accuracy of the network for training set is {}%'.format(100 * correct / total))
# Out:
# Accuracy of the network for training set is 64.98194945848375%

# %% [markdown]
# Now time to see the accuracy of the test set.

# %%
correct, total = DetermineAccuracy('test')
print('Accuracy of the network for test set is {}%'.format(100 * correct / total))
# Out:
# Accuracy of the network for test set is 60.888888888888886%

# %% [markdown]
# Let's see individual class performance along with the confusion matrix.

# %%
classCorrect = list(0. for i in range(5))
classTotal = list(0. for i in range(5))
confusion = torch.zeros(5, 5)

for i, data in enumerate(testLoader):
    inputs, labels = data
    if useGPU:
        inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
    else:
        inputs, labels = Variable(inputs), Variable(labels)
    
    outputs = net(inputs)
    _, predicted = torch.max(outputs.data, 1)

    classTotal[labels.data.cpu().numpy()[0]] += 1
    confusion[labels.data.cpu().numpy()[0]][predicted[0][0]] += 1
    
    if labels.data.cpu().numpy()[0] == predicted.cpu().numpy()[0][0]:
        classCorrect[labels.data.cpu().numpy()[0]] += 1

for i, cls in enumerate(classCorrect):
    print('Class ' + datasetClasses[i] + ' total: ' + str(classTotal[i]) + ' correct: ' + str(classCorrect[i]) + ' success rate is ' + str(100 * classCorrect[i] / classTotal[i])) 

    
# Normalize confusion matrix
for i in range(5):
    confusion[i] = confusion[i] / confusion[i].sum()
    
# Plot confusion matrix
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(confusion.numpy())
fig.colorbar(cax)

ax.set_xticklabels([''] + datasetClasses, rotation=90)
ax.set_yticklabels([''] + datasetClasses)

# Force label at every tick
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

plt.show()
# Out:
# Class daisy total: 200.0 correct: 113.0 success rate is 56.5
# Class dandelion total: 230.0 correct: 156.0 success rate is 67.82608695652173
# Class roses total: 120.0 correct: 51.0 success rate is 42.5
# Class sunflowers total: 170.0 correct: 141.0 success rate is 82.94117647058823
# Class tulips total: 180.0 correct: 95.0 success rate is 52.77777777777778

# %% [markdown]
# Results are looking good, let's save the model for future use.

# %%
torch.save(net, 'FlowerCNN.net')
# Out:
# I:\Anaconda3\envs\PyTorchEnv\lib\site-packages\torch\serialization.py:147: UserWarning: Couldn't retrieve source code for container of type Net. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
