# %% [markdown]
# # Surface Defect Detection

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# In this notebook, we are going to create a convolutional neural network (CNN) that can detect surface defects.
# Previously we have used Torch but now PyTorch will be used.
#
# PyTorch is the freshest flavour of the Torch. It combines customization of Torch with Python ease of use. It completely covers the Torch functionality, on top of that, new Autograd mechanism, dataset loaders and lots of utilities have been added for convenience.

# %% [markdown]
# ## 2. Code
#
# First, let's import required packages...

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import numpy as np
import time
import copy
import os
import PIL
# %matplotlib inline
plt.ion()

# %% [markdown]
# ## 2.1 Dataset transformations
# PyTorch lets us define a set of transformations to the loaded datasets.
#
# First images are converted to Torch tensors and then we will be scaling the images to 64 pixels in the smaller dimension.

# %%
baseDirectory = 'f:/Datasets'
setDirectory = 'Aviles'
setImageSize = 128

# Aviles mean and std values
#0.428152725978
#0.0236011128166
setMean = [0.428, 0.428, 0.428]
setStd = [0.023, 0.023, 0.023]

dataTransforms = {
    'train': transforms.Compose([
        transforms.Scale(setImageSize),
        transforms.RandomCrop(setImageSize),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=setMean, std=setStd)
    ]),
    'test': transforms.Compose([
        transforms.Scale(setImageSize),
        transforms.RandomCrop(setImageSize),
        transforms.ToTensor(),
        transforms.Normalize(mean=setMean, std=setStd)
    ]),
}

# %% [markdown]
# ## 2.2 Loading datasets
# Unlike Torch, PyTorch now supports direct image folder loading as the data. This completely removes the big dataset preparation step.
#
# Additionally new dataset loaders allow setting batch size, shuffle and several other useful parameters.
#
# Lastly checking the CUDA support is now easier with `torch.cuda.is_available()`

# %%
setPath = os.path.join(baseDirectory, setDirectory)
datasets = {x: torchvision.datasets.ImageFolder(os.path.join(setPath, x), dataTransforms[x])
           for x in ['train', 'test']}

datasetLoaders = {x: torch.utils.data.DataLoader(datasets[x], batch_size=4, shuffle=True, num_workers=4)
                for x in ['train', 'test']}

testLoader = torch.utils.data.DataLoader(datasets['test'], batch_size=1, shuffle=False, num_workers=4)

datasetSizes = {x: len(datasets[x]) for x in ['train', 'test']}
datasetClasses = datasets['train'].classes

useGPU = torch.cuda.is_available()

print(str(datasetSizes) + ' images will be used.' )
print('GPU will ' + ('' if useGPU else 'not ') + 'be used.' )
# Out:
# {'train': 361, 'test': 3537} images will be used.
# GPU will be used.

# %% [markdown]
# ## 2.3 Auxiliary functions
#
# ### 2.3.1 ImShow
# Here we define the simple image displaying function and use the new dataset iterator to get one random batch to display it.

# %%
def ImShow(input, title=None):
    input = input.numpy().transpose((1, 2, 0))
    input = setStd * input + setMean
    plt.figure(figsize=(8,8))
    plt.imshow(input)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

inputs, classes = next(iter(datasetLoaders['train']))
out = torchvision.utils.make_grid(inputs)
ImShow(out, title=[datasetClasses[x] for x in classes])

# %% [markdown]
# ### 2.3.2 VisualizeModel
#
# This function helps displaying the predictions of the network.

# %%
def VisualizeModel(model, numImages=6):
    imagesSoFar = 0
    fig = plt.figure()
    
    for i, data in enumerate(datasetLoaders['test']):
        inputs, labels = data
        if useGPU:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)
        
        outputs = model(inputs)
        _, preds = torch.max(outputs.data, 1)
        
        for j in range(inputs.size()[0]):
            imagesSoFar += 1
            ax = plt.subplot(numImages // 2, 2, imagesSoFar)
            ax.axis('off')
            ax.set_title('Predicted: {}'.format(datasetClasses[labels.data[j]]))
            ImShow(inputs.cpu().data[j])
            
            if imagesSoFar == numImages:
                return

# %% [markdown]
# ## 2.4 Training functions
#
# This section contains functions used in training the network.

# %% [markdown]
# ### 2.4.1 TrainModelMiniBatch
#
# Here we have 2 different training functions. First one uses mini batches and a separate learning-rate scheduler function for training.

# %%
def TrainModelMiniBatch(model, criterion, optimizer, lr_scheduler, num_epochs=25):
    since = time.time()

    best_model = model
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'test']:
            if phase == 'train':
                optimizer = lr_scheduler(optimizer, epoch)
                model.train(True)  # Set model to training mode
            else:
                model.train(False)  # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for data in datasetLoaders[phase]:
                # get the inputs
                inputs, labels = data

                # wrap them in Variable
                if useGPU:
                    inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
                else:
                    inputs, labels = Variable(inputs), Variable(labels)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                # backward + optimize only if in training phase
                if phase == 'train':
                    loss.backward()
                    optimizer.step()

                # statistics
                running_loss += loss.data[0]
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / datasetSizes[phase]
            epoch_acc = running_corrects / datasetSizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'test' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model = copy.deepcopy(model)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))
    return best_model

# %% [markdown]
# ### 2.4.2 TrainModelBatch
#
# This is the previous method of training which uses all of the images in the training set for each training iteration.

# %%
def TrainModelBatch(model, criterion, optimizer, lrDecay, maxIteration):
    currentIteration = 0
    startTime = time.time()
    trainSetSize = datasetSizes['train']
    
    shuffledIndices = torch.randperm(trainSetSize)
    print('Started training...')
    
    while True:
        runningLoss = 0
        for iInput, data in enumerate(datasetLoaders['train'], 0):
            inputs, labels = data
            if useGPU:
                inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
            else:
                inputs, labels = Variable(inputs), Variable(labels)
            
            optimizer.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            #print(iInput)
            runningLoss += loss.data[0]
            
        currentError = runningLoss / trainSetSize
        print('Iteration: ' + str(currentIteration) + '# current error = ' + str(currentError))
        currentIteration += 1
        
        if maxIteration > 0 and currentIteration > maxIteration:
            print('# Maximum iteration reached. End of training.')
            print('# Training error = ' + str(currentError))
            timeElapsed = time.time() - startTime            
            print('Training complete in {:.0f}m {:.0f}s'.format(timeElapsed // 60, timeElapsed % 60))
            break

# %% [markdown]
# ### 2.4.3 ExpLRScheduler
#
# Updates the learning-rate after each `lr_decay_epoch` number of epochs.

# %%
def ExpLRScheduler(optimizer, epoch, init_lr=0.001, lr_decay_epoch=7):
    lr = init_lr * (0.1 ** (epoch // lr_decay_epoch))
    
    if epoch % lr_decay_epoch == 0:
        print('LR is set to {}'.format(lr))
        
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    
    return optimizer

# %% [markdown]
# ## 2.5 Definition of neural network
#
# ### 2.5.1 Network module
# Similar to Torch, here we define the neural network using separate modules.
# First module handles the convolutional part of the network. After that a reshape operation adjust the convolution result for the following fully-connected layer module. Lastly, the result is applied to the fully-connected layer of the network and decisions are obtained with LogSoftMax operation in the end.

# %%
# Currently, weights are not shared.
# TODO: Try weight sharing with looping the element
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1)),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1)),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1)),
            nn.ReLU(),
            nn.MaxPool2d(2, 2))
    
        self.outMul = int(setImageSize / 8) 
            
        self.fc = nn.Sequential(
            nn.Linear(32 * self.outMul * self.outMul, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 2)) # number of classes
        
        self.logsmax = nn.LogSoftmax()

    def forward(self, x):
        # Apply inputs to convolutional module of the network
        x = self.conv(x)
        
        # Reshape the result for fully-connected layers
        x = x.view(-1, 32 * self.outMul * self.outMul)
        
        # Apply the result to fully-connected layers
        x = self.fc(x)
        
        # Finally apply the LogSoftMax for output
        x = self.logsmax(x)
        return x

net = Net()
if useGPU:
    net = net.cuda()

# %% [markdown]
# ### 2.5.2 Criterion and optimizer
# We successfully created our neural network. Now it is time to define a loss function and the optimizer.

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

if useGPU:
    criterion = criterion.cuda()

# %% [markdown]
# ## 2.6 Training
#
# Mini-batch training method is preferred with PyTorch. It converges faster than the batch training method.
#
# *Example*
#
# *Mini-batch : With GTX 1070, 50 epochs train in  with 95.5% train and 75.7% test accuracy.*
#
# *Batch      : With GTX 1070, 80 epochs train in  with .5% train and .3% test accuracy.*

# %%
TrainModelMiniBatch(net, criterion, optimizer, ExpLRScheduler, num_epochs=80)
# Out:
# Epoch 0/79
# ----------
# LR is set to 0.001
# train Loss: 0.1724 Acc: 0.5679
# test Loss: 0.1765 Acc: 0.3265
#
# Epoch 1/79
# ----------
# train Loss: 0.1690 Acc: 0.5928
# test Loss: 0.1765 Acc: 0.3274
#
# Epoch 2/79
# ----------
# train Loss: 0.1623 Acc: 0.5956
# test Loss: 0.1631 Acc: 0.4543
#
# Epoch 3/79
# ----------
# train Loss: 0.1412 Acc: 0.7701
# test Loss: 0.1661 Acc: 0.7537
#
# Epoch 4/79
# ----------
# train Loss: 0.0708 Acc: 0.9114
# test Loss: 0.2140 Acc: 0.7464
#
# Epoch 5/79
# ----------
# train Loss: 0.0597 Acc: 0.9363
# test Loss: 0.4047 Acc: 0.7178
#
# Epoch 6/79
# ----------
# train Loss: 0.0465 Acc: 0.9391
# test Loss: 0.1953 Acc: 0.8055
#
# Epoch 7/79
# ----------
# LR is set to 0.0001
# train Loss: 0.0409 Acc: 0.9363
# test Loss: 0.4553 Acc: 0.7543
#
# Epoch 8/79
# ----------
# train Loss: 0.0359 Acc: 0.9474
# test Loss: 0.5668 Acc: 0.7580
#
# Epoch 9/79
# ----------
# train Loss: 0.0325 Acc: 0.9612
# test Loss: 0.4203 Acc: 0.7563
#
# Epoch 10/79
# ----------
# train Loss: 0.0401 Acc: 0.9557
# test Loss: 0.5812 Acc: 0.7560
#
# Epoch 11/79
# ----------
# train Loss: 0.0409 Acc: 0.9640
# test Loss: 0.3575 Acc: 0.7552
#
# Epoch 12/79
# ----------
# train Loss: 0.0311 Acc: 0.9474
# test Loss: 0.4355 Acc: 0.7569
#
# Epoch 13/79
# ----------
# train Loss: 0.0330 Acc: 0.9584
# test Loss: 0.4736 Acc: 0.7543
#
# Epoch 14/79
# ----------
# LR is set to 1.0000000000000003e-05
# train Loss: 0.0353 Acc: 0.9584
# test Loss: 0.4676 Acc: 0.7563
#
# Epoch 15/79
# ----------
# train Loss: 0.0329 Acc: 0.9584
# test Loss: 0.4630 Acc: 0.7560
#
# Epoch 16/79
# ----------
# train Loss: 0.0290 Acc: 0.9723
# test Loss: 0.4392 Acc: 0.7560
#
# Epoch 17/79
# ----------
# train Loss: 0.0340 Acc: 0.9584
# test Loss: 0.4386 Acc: 0.7574
#
# Epoch 18/79
# ----------
# train Loss: 0.0400 Acc: 0.9584
# test Loss: 0.4324 Acc: 0.7586
#
# Epoch 19/79
# ----------
# train Loss: 0.0358 Acc: 0.9557
# test Loss: 0.4360 Acc: 0.7586
#
# Epoch 20/79
# ----------
# train Loss: 0.0375 Acc: 0.9529
# test Loss: 0.4386 Acc: 0.7583
#
# Epoch 21/79
# ----------
# LR is set to 1.0000000000000002e-06
# train Loss: 0.0337 Acc: 0.9584
# test Loss: 0.4390 Acc: 0.7566
#
# Epoch 22/79
# ----------
# train Loss: 0.0316 Acc: 0.9612
# test Loss: 0.4434 Acc: 0.7594
#
# Epoch 23/79
# ----------
# train Loss: 0.0349 Acc: 0.9668
# test Loss: 0.4511 Acc: 0.7580
#
# Epoch 24/79
# ----------
# train Loss: 0.0355 Acc: 0.9612
# test Loss: 0.4407 Acc: 0.7552
#
# Epoch 25/79
# ----------
# train Loss: 0.0378 Acc: 0.9612
# test Loss: 0.4383 Acc: 0.7549
#
# Epoch 26/79
# ----------
# train Loss: 0.0293 Acc: 0.9695
# test Loss: 0.4271 Acc: 0.7580
#
# Epoch 27/79
# ----------
# train Loss: 0.0281 Acc: 0.9612
# test Loss: 0.4338 Acc: 0.7569
#
# Epoch 28/79
# ----------
# LR is set to 1.0000000000000002e-07
# train Loss: 0.0346 Acc: 0.9612
# test Loss: 0.4364 Acc: 0.7566
#
# Epoch 29/79
# ----------
# train Loss: 0.0323 Acc: 0.9584
# test Loss: 0.4329 Acc: 0.7560
#
# Epoch 30/79
# ----------
# train Loss: 0.0350 Acc: 0.9584
# test Loss: 0.4305 Acc: 0.7588
#
# Epoch 31/79
# ----------
# train Loss: 0.0362 Acc: 0.9501
# test Loss: 0.4402 Acc: 0.7566
#
# Epoch 32/79
# ----------
# train Loss: 0.0317 Acc: 0.9668
# test Loss: 0.4386 Acc: 0.7557
#
# Epoch 33/79
# ----------
# train Loss: 0.0360 Acc: 0.9612
# test Loss: 0.4289 Acc: 0.7588
#
# Epoch 34/79
# ----------
# train Loss: 0.0356 Acc: 0.9612
# test Loss: 0.4440 Acc: 0.7577
#
# Epoch 35/79
# ----------
# LR is set to 1.0000000000000004e-08
# train Loss: 0.0352 Acc: 0.9612
# test Loss: 0.4497 Acc: 0.7549
#
# Epoch 36/79
# ----------
# train Loss: 0.0327 Acc: 0.9584
# test Loss: 0.4465 Acc: 0.7554
#
# Epoch 37/79
# ----------
# train Loss: 0.0343 Acc: 0.9557
# test Loss: 0.4362 Acc: 0.7560
#
# Epoch 38/79
# ----------
# train Loss: 0.0317 Acc: 0.9640
# test Loss: 0.4404 Acc: 0.7594
#
# Epoch 39/79
# ----------
# train Loss: 0.0314 Acc: 0.9640
# test Loss: 0.4332 Acc: 0.7597
#
# Epoch 40/79
# ----------
# train Loss: 0.0324 Acc: 0.9584
# test Loss: 0.4441 Acc: 0.7586
#
# Epoch 41/79
# ----------
# train Loss: 0.0308 Acc: 0.9640
# test Loss: 0.4267 Acc: 0.7571
#
# Epoch 42/79
# ----------
# LR is set to 1.0000000000000005e-09
# train Loss: 0.0388 Acc: 0.9557
# test Loss: 0.4337 Acc: 0.7563
#
# Epoch 43/79
# ----------
# train Loss: 0.0292 Acc: 0.9668
# test Loss: 0.4501 Acc: 0.7586
#
# Epoch 44/79
# ----------
# train Loss: 0.0313 Acc: 0.9668
# test Loss: 0.4371 Acc: 0.7591
#
# Epoch 45/79
# ----------
# train Loss: 0.0345 Acc: 0.9557
# test Loss: 0.4438 Acc: 0.7580
#
# Epoch 46/79
# ----------
# train Loss: 0.0337 Acc: 0.9612
# test Loss: 0.4448 Acc: 0.7566
#
# Epoch 47/79
# ----------
# train Loss: 0.0335 Acc: 0.9584
# test Loss: 0.4408 Acc: 0.7543
#
# Epoch 48/79
# ----------
# train Loss: 0.0335 Acc: 0.9612
# test Loss: 0.4429 Acc: 0.7591
#
# Epoch 49/79
# ----------
# LR is set to 1.0000000000000004e-10
# train Loss: 0.0322 Acc: 0.9640
# test Loss: 0.4441 Acc: 0.7588
#
# Epoch 50/79
# ----------
# train Loss: 0.0315 Acc: 0.9612
# test Loss: 0.4439 Acc: 0.7552
#
# Epoch 51/79
# ----------
# train Loss: 0.0304 Acc: 0.9668
# test Loss: 0.4410 Acc: 0.7574
#
# Epoch 52/79
# ----------
# train Loss: 0.0343 Acc: 0.9557
# test Loss: 0.4321 Acc: 0.7577
#
# Epoch 53/79
# ----------
# train Loss: 0.0389 Acc: 0.9529
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# <ipython-input-11-f3a45a794cbc> in <module>()
# ----> 1 TrainModelMiniBatch(net, criterion, optimizer, ExpLRScheduler, num_epochs=80)
#
# <ipython-input-6-14412616a1d4> in TrainModelMiniBatch(model, criterion, optimizer, lr_scheduler, num_epochs)
#      21
#      22             # Iterate over data.
# ---> 23             for data in datasetLoaders[phase]:
#      24                 # get the inputs
#      25                 inputs, labels = data
#
# I:\Anaconda3\envs\PyTorchEnv\lib\site-packages\torch\utils\data\dataloader.py in __iter__(self)
#     301
#     302     def __iter__(self):
# --> 303         return DataLoaderIter(self)
#     304
#     305     def __len__(self):
#
# I:\Anaconda3\envs\PyTorchEnv\lib\site-packages\torch\utils\data\dataloader.py in __init__(self, loader)
#     160             for w in self.workers:
#     161                 w.daemon = True  # ensure that the worker exits on process exit
# --> 162                 w.start()
#     163
#     164             if self.pin_memory:
#
# I:\Anaconda3\envs\PyTorchEnv\lib\multiprocessing\process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         _children.add(self)
#
# I:\Anaconda3\envs\PyTorchEnv\lib\multiprocessing\context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# I:\Anaconda3\envs\PyTorchEnv\lib\multiprocessing\context.py in _Popen(process_obj)
#     320         def _Popen(process_obj):
#     321             from .popen_spawn_win32 import Popen
# --> 322             return Popen(process_obj)
#     323
#     324     class SpawnContext(BaseContext):
#
# I:\Anaconda3\envs\PyTorchEnv\lib\multiprocessing\popen_spawn_win32.py in __init__(self, process_obj)
#      63             try:
#      64                 reduction.dump(prep_data, to_child)
# ---> 65                 reduction.dump(process_obj, to_child)
#      66             finally:
#      67                 set_spawning_popen(None)
#
# I:\Anaconda3\envs\PyTorchEnv\lib\multiprocessing\reduction.py in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#      61
#      62 #
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
TrainModelBatch(net, criterion, optimizer, 0.000011875, maxIteration=80)
# Out:
# Started training...
# Iteration: 0# current error = 0.17217081166570622
# Iteration: 1# current error = 0.16959477855503263
# Iteration: 2# current error = 0.16598697853638272
# Iteration: 3# current error = 0.150841492208264
# Iteration: 4# current error = 0.14654663018575415
# Iteration: 5# current error = 0.12928602037432754
# Iteration: 6# current error = 0.1285702009950772
# Iteration: 7# current error = 0.11336444263059578
# Iteration: 8# current error = 0.11928746888576662
# Iteration: 9# current error = 0.09368524077475758
# Iteration: 10# current error = 0.09532898074688
# Iteration: 11# current error = 0.07708430509934512
# Iteration: 12# current error = 0.07789893367610062
# Iteration: 13# current error = 0.07937282866156235
# Iteration: 14# current error = 0.0719367282336027
# Iteration: 15# current error = 0.06914884916850392
# Iteration: 16# current error = 0.0652122594693467
# Iteration: 17# current error = 0.056864759759728906
# Iteration: 18# current error = 0.04856232104448671
# Iteration: 19# current error = 0.0597256770876468
# Iteration: 20# current error = 0.047833087517163766
# Iteration: 21# current error = 0.03995865625387811
# Iteration: 22# current error = 0.05520403953876133
# Iteration: 23# current error = 0.06205083279685627
# Iteration: 24# current error = 0.04718914769673904
# Iteration: 25# current error = 0.035156587595515154
# Iteration: 26# current error = 0.03450262433278897
# Iteration: 27# current error = 0.0363353426728461
# Iteration: 28# current error = 0.027037771359935
# Iteration: 29# current error = 0.033002340981261
# Iteration: 30# current error = 0.04413123026560897
# Iteration: 31# current error = 0.03574483731005546
# Iteration: 32# current error = 0.027719848995854352
# Iteration: 33# current error = 0.029622441641674924
# Iteration: 34# current error = 0.03254536972523337
# Iteration: 35# current error = 0.03401980428304459
# Iteration: 36# current error = 0.024745054137576803
# Iteration: 37# current error = 0.02281406775823283
# Iteration: 38# current error = 0.018807929005684402
# Iteration: 39# current error = 0.025991054506238793
# Iteration: 40# current error = 0.02049257874567143
# Iteration: 41# current error = 0.020922655989388615
# Iteration: 42# current error = 0.026798236940551712
# Iteration: 43# current error = 0.029448662911176954
# Iteration: 44# current error = 0.020732083070068696
# Iteration: 45# current error = 0.016716150096900587
# Iteration: 46# current error = 0.027417731324917597
# Iteration: 47# current error = 0.018248411491864864
# Iteration: 48# current error = 0.01945678554131258
# Iteration: 49# current error = 0.019136683757846495
# Iteration: 50# current error = 0.03611157149310875
# Iteration: 51# current error = 0.024336368417366118
# Iteration: 52# current error = 0.02483407764614702
# Iteration: 53# current error = 0.020473354506339317
# Iteration: 54# current error = 0.022036759333082682
# Iteration: 55# current error = 0.015425774329646981
# Iteration: 56# current error = 0.016228354513368924
# Iteration: 57# current error = 0.03469928574841623
# Iteration: 58# current error = 0.017757916784571528
# Iteration: 59# current error = 0.03216812336577438
# Iteration: 60# current error = 0.026447551377166617
# Iteration: 61# current error = 0.015421099362107747
# Iteration: 62# current error = 0.01721425836515033
# Iteration: 63# current error = 0.021347568908061564
# Iteration: 64# current error = 0.010902880346492198
# Iteration: 65# current error = 0.022928772940476353
# Iteration: 66# current error = 0.020452956558131907
# Iteration: 67# current error = 0.02415308642430708
# Iteration: 68# current error = 0.028426186845527005
# Iteration: 69# current error = 0.015597733899443621
# Iteration: 70# current error = 0.01778958390421359
# Iteration: 71# current error = 0.01020061789834755
# Iteration: 72# current error = 0.021359953576155822
# Iteration: 73# current error = 0.014880489333515726
# Iteration: 74# current error = 0.010273608199417996
# Iteration: 75# current error = 0.019277177739663965
# Iteration: 76# current error = 0.014383869957071022
# Iteration: 77# current error = 0.010984024170702138
# Iteration: 78# current error = 0.015390732795662592
# Iteration: 79# current error = 0.021247783149685357
# Iteration: 80# current error = 0.006377628996095784
# # Maximum iteration reached. End of training.
# # Training error = 0.006377628996095784
# Training complete in 7m 32s

# %% [markdown]
# ## 2.7 Visualization of the weights
#
# This section is still in development.

# %%
#VisualizeModel(net)

# %%
# IN PROGRESS...
def plot_kernels(tensor, num_cols=6):
    if not tensor.ndim==4:
        raise Exception("assumes a 4D tensor")
    if not tensor.shape[-1]==3:
        raise Exception("last dim needs to be 3 to plot")
    num_kernels = tensor.shape[0]
    num_rows = 1+ num_kernels // num_cols
    fig = plt.figure(figsize=(num_cols,num_rows))
    for i in range(tensor.shape[0]):
        ax1 = fig.add_subplot(num_rows,num_cols,i+1)
        ax1.imshow(tensor[i])
        ax1.axis('off')
        ax1.set_xticklabels([])
        ax1.set_yticklabels([])

    plt.subplots_adjust(wspace=0.1, hspace=0.1)
    plt.show()
#plot_kernels(net.conv[6].weight.cpu().data.numpy())

# %%
import math
def plotNNFilter(units):
    filters = units.shape[3]
    plt.figure(1, figsize=(20,20))
    n_columns = 6
    n_rows = math.ceil(filters / n_columns) + 1
    for i in range(filters):
        plt.subplot(n_rows, n_columns, i+1)
        plt.title('Filter ' + str(i))
        plt.imshow(units[0,:,:,i], interpolation="nearest", cmap="gray")

# %%
plotNNFilter(net.conv[6].weight.cpu().data.numpy())

# %% [markdown]
# ## 2.8 Evaluating network accuracy
# Let's calculate the accuracy on the training set.

# %%
def DetermineAccuracy(phase):
    correct = 0
    total = 0
    for data in datasetLoaders[phase]:
        # Inputs
        inputs, labels = data
        if useGPU:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        outputs = net(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.data).sum()
    return correct, total

# %%
correct, total = DetermineAccuracy('train')
print('Accuracy of the network for training set is {}%'.format(100 * correct / total))
# Out:
# Accuracy of the network for training set is 98.51729818780889%

# %% [markdown]
# Now time to see the accuracy of the test set.

# %%
correct, total = DetermineAccuracy('test')
print('Accuracy of the network for test set is {}%'.format(100 * correct / total))
# Out:
# Accuracy of the network for test set is 99.35691318327974%

# %% [markdown]
# Let's see individual class performance.

# %%
classCorrect = list(0. for i in range(2))
classTotal = list(0. for i in range(2))

for i, data in enumerate(testLoader):
    inputs, labels = data
    if useGPU:
        inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
    else:
        inputs, labels = Variable(inputs), Variable(labels)
    
    outputs = net(inputs)
    _, predicted = torch.max(outputs.data, 1)

    classTotal[labels.data.cpu().numpy()[0]] += 1
    
    if labels.data.cpu().numpy()[0] == predicted.cpu().numpy()[0][0]:
        classCorrect[labels.data.cpu().numpy()[0]] += 1

for i, cls in enumerate(classCorrect):
    print('Class ' + datasetClasses[i] + ' total: ' + str(classTotal[i]) + ' correct: ' + str(classCorrect[i]) + ' success rate is ' + str(100 * classCorrect[i] / classTotal[i]))
# Out:
# Class defect total: 181.0 correct: 180.0 success rate is 99.4475138121547
# Class nonDefect total: 130.0 correct: 129.0 success rate is 99.23076923076923

# %% [markdown]
# Results are looking good, let's save the model for future use.

# %%
torch.save(net.state_dict(), 'AachenCNN.net')
