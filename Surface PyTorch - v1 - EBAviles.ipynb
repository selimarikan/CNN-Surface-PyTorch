# %% [markdown]
# # Surface Defect Detection for EBAvilesDataset

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# In this notebook, we are going to create a convolutional neural network (CNN) that can detect surface defects.
# Previously we have used Torch but now PyTorch will be used.
#
# PyTorch is the freshest flavour of the Torch. It combines customization of Torch with Python ease of use. It completely covers the Torch functionality, on top of that, new Autograd mechanism, dataset loaders and lots of utilities have been added for convenience.

# %% [markdown]
# ## 2. Code
#
# First, let's import required packages...

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file
from bokeh.palettes import Spectral7
from bokeh.io import output_notebook
#from graphviz import Digraph
import numpy as np
import cnnUtils
import time
import copy
import os
import PIL
# %matplotlib inline
plt.ion()
output_notebook()
# Out:
# Please install sklearn for layer visualization
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c9eba3b3-f381-46ca-9103-b2cf22a095d1">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## 2.1 Dataset transformations
# PyTorch lets us define a set of transformations to the loaded datasets.
#
# First images are converted to Torch tensors and then we will be scaling the images to 64 pixels in the smaller dimension.

# %%
baseDirectory = 'g:/Selim/Thesis/Code/'
setDirectory = 'EBAviles'
setImageSize = 128

# EBAviles cropped mean and std values
#Dim 0 mean: 0.523099429903
#Dim 0 stdv: 0.0497442047553
setMean = [0.523, 0.523, 0.523]
setStd = [0.049, 0.049, 0.049]

dataTransforms = {
    'train': transforms.Compose([
        transforms.Scale(setImageSize),
        transforms.RandomCrop(setImageSize),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=setMean, std=setStd)
    ]),
    'test': transforms.Compose([
        transforms.Scale(setImageSize),
        #transforms.CenterCrop(setImageSize),
        transforms.RandomCrop(setImageSize),
        transforms.ToTensor(),
        transforms.Normalize(mean=setMean, std=setStd)
    ]),
}

# %% [markdown]
# ## 2.2 Loading datasets
# Unlike Torch, PyTorch now supports direct image folder loading as the data. This completely removes the big dataset preparation step.
#
# Additionally new dataset loaders allow setting batch size, shuffle and several other useful parameters.
#
# Lastly checking the CUDA support is now easier with `torch.cuda.is_available()`

# %%
setPath = os.path.join(baseDirectory, setDirectory)
datasets = {x: torchvision.datasets.ImageFolder(os.path.join(setPath, x), dataTransforms[x])
           for x in ['train', 'test']}

datasetLoaders = {x: torch.utils.data.DataLoader(datasets[x], batch_size=64, shuffle=True, num_workers=4, pin_memory=True)
                for x in ['train', 'test']}

testLoader = torch.utils.data.DataLoader(datasets['test'], batch_size=1, shuffle=False, num_workers=4, pin_memory=True)

datasetSizes = {x: len(datasets[x]) for x in ['train', 'test']}
datasetClasses = datasets['train'].classes

useGPU = torch.cuda.is_available()

print(str(datasetSizes) + ' images will be used.' )
print('GPU will ' + ('' if useGPU else 'not ') + 'be used.' )
print(str(len(datasetClasses)) + ' output classes')
# Out:
# {'train': 754, 'test': 3848} images will be used.
# GPU will be used.
# 2 output classes

# %% [markdown]
# ## 2.3 Auxiliary functions
#
# ### 2.3.1 ImShow
# Here we define the simple image displaying function and use the new dataset iterator to get one random batch to display it.

# %%
inputs, classes = next(iter(datasetLoaders['train']))
out = torchvision.utils.make_grid(inputs)

cnnUtils.ImShow(out, mean=setMean, std=setStd, title=[datasetClasses[x] for x in classes])
#print(inputs)

# %% [markdown]
# # 2.4 Training functions
#
# This section contains functions used in training the network. First we should create the arrays to keep the error and learning rate changes.

# %%
trainLRValues = []
trainAccuracyTrain = []
trainAccuracyTest = []
trainErrorTrain = []
trainErrorTest = []

grads = {}
def save_grad(name):
    def hook(grad):
        grads[name] = grad
    return hook

# %% [markdown]
# ## 2.5 Definition of neural network
#
# ### 2.5.1 Network module
# Similar to Torch, here we define the neural network using separate modules.
# First module handles the convolutional part of the network. After that a reshape operation adjust the convolution result for the following fully-connected layer module. Lastly, the result is applied to the fully-connected layer of the network and decisions are obtained with LogSoftMax operation in the end.

# %%
# Currently, weights are not shared.
# TODO: Try weight sharing with looping the element
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.convIn = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.reluIn = nn.ReLU()
        self.poolIn = nn.MaxPool2d(2, 2)
        
        self.convI2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.reluI2 = nn.ReLU()
        self.poolI2 = nn.MaxPool2d(2, 2)
        
        self.convI3 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.reluI3 = nn.ReLU()
        self.poolI3 = nn.MaxPool2d(2, 2)
        
        self.outMul = int(setImageSize / 8) 
            
        self.fc = nn.Sequential(
            nn.Linear(32 * self.outMul * self.outMul, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096, len(datasetClasses))) # number of classes
        
        self.logsmax = nn.LogSoftmax()

    def forward(self, x):
        # Convolutional layer 1
        convInResult = self.convIn(x)
        convInResult.register_hook(save_grad('convInGrad'))
        x = self.poolIn(self.reluIn(convInResult))
        
        # Convolutional layer 2
        convI2Result = self.convI2(x)
        convI2Result.register_hook(save_grad('convI2Grad'))
        x = self.poolI2(self.reluI2(convI2Result))
        
        # Convolutional layer 3
        convI3Result = self.convI3(x)
        convI3Result.register_hook(save_grad('convI3Grad'))
        x = self.poolI3(self.reluI3(convI3Result))
        
        
        # Reshape the result for fully-connected layers
        x = x.view(-1, 32 * self.outMul * self.outMul)
        
        # Apply the result to fully-connected layers
        x = self.fc(x)
        
        # Finally apply the LogSoftMax for output
        x = self.logsmax(x)
        return x

# %% [markdown]
# #### 2.5.1.2 Batch normalization - TEST

# %%
# Currently, weights are not shared.
# TODO: Try weight sharing with looping the element
class NetBN(nn.Module):
    def __init__(self):
        super(NetBN, self).__init__()
        self.convIn = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.batNIn = nn.BatchNorm2d(num_features=32)
        self.reluIn = nn.ReLU()
        self.poolIn = nn.MaxPool2d(2, 2)
        
        self.convI2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.batNI2 = nn.BatchNorm2d(num_features=32)
        self.reluI2 = nn.ReLU()
        self.poolI2 = nn.MaxPool2d(2, 2)
        
        self.convI3 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.batNI3 = nn.BatchNorm2d(num_features=32)
        self.reluI3 = nn.ReLU()
        self.poolI3 = nn.MaxPool2d(2, 2)
        
        self.outMul = int(setImageSize / 8) 
            
        self.fc = nn.Sequential(
            nn.Linear(32 * self.outMul * self.outMul, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(4096, len(datasetClasses))) # number of classes
        
        self.logsmax = nn.LogSoftmax()

    def forward(self, x):
        # Convolutional layer 1
        convInResult = self.convIn(x)
        convInResult.register_hook(save_grad('convInGrad'))
        x = self.poolIn(self.reluIn(self.batNIn(convInResult)))
        
        # Convolutional layer 2
        convI2Result = self.convI2(x)
        convI2Result.register_hook(save_grad('convI2Grad'))
        x = self.poolI2(self.reluI2(self.batNI2(convI2Result)))
        
        # Convolutional layer 3
        convI3Result = self.convI3(x)
        convI3Result.register_hook(save_grad('convI3Grad'))
        x = self.poolI3(self.reluI3(self.batNI3(convI3Result)))
        
        # Reshape the result for fully-connected layers
        x = x.view(-1, 32 * self.outMul * self.outMul)
        
        # Apply the result to fully-connected layers
        x = self.fc(x)
        
        # Finally apply the LogSoftMax for output
        x = self.logsmax(x)
        return x

# %% [markdown]
# #### 2.5.1.4 Batch normalization + SELU + AlphaDropout

# %%
# Currently, weights are not shared.
# TODO: Try weight sharing with looping the element
class NetBNSELU(nn.Module):
    def __init__(self):
        super(NetBNSELU, self).__init__()
        self.convIn = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.batNIn = nn.BatchNorm2d(num_features=32)
        self.seluIn = SELU()
        self.poolIn = nn.MaxPool2d(2, 2)
        
        self.convI2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.batNI2 = nn.BatchNorm2d(num_features=32)
        self.seluI2 = SELU()
        self.poolI2 = nn.MaxPool2d(2, 2)
        
        self.convI3 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=(3,3), stride=(1,1), padding=(1,1))
        self.batNI3 = nn.BatchNorm2d(num_features=32)
        self.seluI3 = SELU()
        self.poolI3 = nn.MaxPool2d(2, 2)
        
        self.outMul = int(setImageSize / 8) 
            
        self.fc = nn.Sequential(
            nn.Linear(32 * self.outMul * self.outMul, 4096),
            SELU(),
            AlphaDropout(p=0.5),
            nn.Linear(4096, 4096),
            SELU(),
            AlphaDropout(p=0.5),
            nn.Linear(4096, 4096),
            SELU(),
            AlphaDropout(p=0.5),
            nn.Linear(4096, len(datasetClasses))) # number of classes
        
        self.logsmax = nn.LogSoftmax()

    def forward(self, x):
        # Convolutional layer 1
        convInResult = self.convIn(x)
        convInResult.register_hook(save_grad('convInGrad'))
        x = self.poolIn(self.seluIn(self.batNIn(convInResult)))
        
        # Convolutional layer 2
        convI2Result = self.convI2(x)
        convI2Result.register_hook(save_grad('convI2Grad'))
        x = self.poolI2(self.seluI2(self.batNI2(convI2Result)))
        
        # Convolutional layer 3
        convI3Result = self.convI3(x)
        convI3Result.register_hook(save_grad('convI3Grad'))
        x = self.poolI3(self.seluI3(self.batNI3(convI3Result)))
        
        # Reshape the result for fully-connected layers
        x = x.view(-1, 32 * self.outMul * self.outMul)
        
        # Apply the result to fully-connected layers
        x = self.fc(x)
        
        # Finally apply the LogSoftMax for output
        x = self.logsmax(x)
        return x

# %% [markdown]
# #### 2.5.1.5 BN + Optim

# %%
class NetBNOptim(nn.Module):
    def __init__(self):
        super(NetBNOptim, self).__init__()
        self.convIn = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(5,5), stride=(1,1), padding=(2,2))
        self.batNIn = nn.BatchNorm2d(num_features=32)
        self.reluIn = nn.ReLU()
        self.poolIn = nn.MaxPool2d(2, 2)
        
        self.convI2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(5,5), stride=(1,1), padding=(2,2))
        self.batNI2 = nn.BatchNorm2d(num_features=64)
        self.reluI2 = nn.ReLU()
        self.poolI2 = nn.MaxPool2d(2, 2)
        
        # Out CH = 32 !
        self.convI3 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=(5,5), stride=(1,1), padding=(2,2))
        self.batNI3 = nn.BatchNorm2d(num_features=32)
        self.reluI3 = nn.ReLU()
        self.poolI3 = nn.MaxPool2d(2, 2)
        
        self.outMul = int(setImageSize / 8) 
            
        self.fc = nn.Sequential(
            nn.Linear(32 * self.outMul * self.outMul, 1024),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(1024, len(datasetClasses))) # number of classes
        
        self.logsmax = nn.LogSoftmax()

    def forward(self, x):
        # Convolutional layer 1
        convInResult = self.convIn(x)
        convInResult.register_hook(save_grad('convInGrad'))
        x = self.poolIn(self.reluIn(self.batNIn(convInResult)))
        
        # Convolutional layer 2
        convI2Result = self.convI2(x)
        convI2Result.register_hook(save_grad('convI2Grad'))
        x = self.poolI2(self.reluI2(self.batNI2(convI2Result)))
        
        # Convolutional layer 3
        convI3Result = self.convI3(x)
        convI3Result.register_hook(save_grad('convI3Grad'))
        x = self.poolI3(self.reluI3(self.batNI3(convI3Result)))
        
        # Reshape the result for fully-connected layers
        x = x.view(-1, 32 * self.outMul * self.outMul)
        
        # Apply the result to fully-connected layers
        x = self.fc(x)
        
        # Finally apply the LogSoftMax for output
        x = self.logsmax(x)
        return x

# %% [markdown]
# #### 2.5.1.6 DilateNet

# %%
class NetDilate(nn.Module):
    def __init__(self):
        super(NetDilate, self).__init__()
        self.convIn = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(5,5), stride=(1,1), padding=(6,6), dilation=(3,3))
        self.batNIn = nn.BatchNorm2d(num_features=32)
        self.reluIn = nn.ReLU()
        self.poolIn = nn.MaxPool2d(2, 2)
        
        self.convI2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(5,5), stride=(1,1), padding=(6,6), dilation=(3,3))
        self.batNI2 = nn.BatchNorm2d(num_features=64)
        self.reluI2 = nn.ReLU()
        self.poolI2 = nn.MaxPool2d(2, 2)
        
        # Out CH = 32 !
        self.convI3 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=(5,5), stride=(1,1), padding=(6,6), dilation=(3,3))
        self.batNI3 = nn.BatchNorm2d(num_features=32)
        self.reluI3 = nn.ReLU()
        self.poolI3 = nn.MaxPool2d(2, 2)
        
        self.outMul = int(setImageSize / 8) 
            
        self.fc = nn.Sequential(
            nn.Linear(32 * self.outMul * self.outMul, 1024),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(1024, len(datasetClasses))) # number of classes
        
        self.logsmax = nn.LogSoftmax()

    def forward(self, x):
        # Convolutional layer 1
        convInResult = self.convIn(x)
        convInResult.register_hook(save_grad('convInGrad'))
        x = self.poolIn(self.reluIn(self.batNIn(convInResult)))
        
        # Convolutional layer 2
        convI2Result = self.convI2(x)
        convI2Result.register_hook(save_grad('convI2Grad'))
        x = self.poolI2(self.reluI2(self.batNI2(convI2Result)))
        
        # Convolutional layer 3
        convI3Result = self.convI3(x)
        convI3Result.register_hook(save_grad('convI3Grad'))
        x = self.poolI3(self.reluI3(self.batNI3(convI3Result)))
        
        # Reshape the result for fully-connected layers
        x = x.view(-1, 32 * self.outMul * self.outMul)
        
        # Apply the result to fully-connected layers
        x = self.fc(x)
        
        # Finally apply the LogSoftMax for output
        x = self.logsmax(x)
        return x

# %% [markdown]
# #### 2.5.1.7 DilateStrideNet

# %%
class NetDilateStride(nn.Module):
    def __init__(self):
        super(NetDilateStride, self).__init__()
        self.convIn = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(5,5), stride=(2,2), padding=(6,6), dilation=(3,3))
        self.batNIn = nn.BatchNorm2d(num_features=32)
        self.reluIn = nn.ReLU()
        #self.poolIn = nn.MaxPool2d(2, 2)
        
        self.convI2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(5,5), stride=(2,2), padding=(6,6), dilation=(3,3))
        self.batNI2 = nn.BatchNorm2d(num_features=64)
        self.reluI2 = nn.ReLU()
        #self.poolI2 = nn.MaxPool2d(2, 2)
        
        # Out CH = 32 !
        self.convI3 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=(5,5), stride=(2,2), padding=(6,6), dilation=(3,3))
        self.batNI3 = nn.BatchNorm2d(num_features=32)
        self.reluI3 = nn.ReLU()
        #self.poolI3 = nn.MaxPool2d(2, 2)
        
        self.outMul = int(setImageSize / 8) 
            
        self.fc = nn.Sequential(
            nn.Linear(32 * self.outMul * self.outMul, 1024),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(1024, len(datasetClasses))) # number of classes
        
        self.logsmax = nn.LogSoftmax()

    def forward(self, x):
        # Convolutional layer 1
        convInResult = self.convIn(x)
        convInResult.register_hook(save_grad('convInGrad'))
        x = self.reluIn(self.batNIn(convInResult))
        
        # Convolutional layer 2
        convI2Result = self.convI2(x)
        convI2Result.register_hook(save_grad('convI2Grad'))
        x = self.reluI2(self.batNI2(convI2Result))
        
        # Convolutional layer 3
        convI3Result = self.convI3(x)
        convI3Result.register_hook(save_grad('convI3Grad'))
        x = self.reluI3(self.batNI3(convI3Result))
        
        # Reshape the result for fully-connected layers
        x = x.view(-1, 32 * self.outMul * self.outMul)
        
        # Apply the result to fully-connected layers
        x = self.fc(x)
        
        # Finally apply the LogSoftMax for output
        x = self.logsmax(x)
        return x

# %% [markdown]
# #### 2.5.1.8 DSPlusNet

# %%
def GetMatchingLayer(inChannels, outChannels, stride=(2,2), padding=(0,0)):
    return nn.Sequential(
            nn.Conv2d(in_channels=inChannels, out_channels=outChannels, kernel_size=(1,1), stride=stride, padding=padding),
            #nn.BatchNorm2d(num_features=outChannels)
    ).cuda()

class DSPlusNet(nn.Module):
    def __init__(self):
        super(DSPlusNet, self).__init__()
        self.convIn = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(5,5), stride=(2,2), padding=(6,6), dilation=(3,3))
        self.batNIn = nn.BatchNorm2d(num_features=32)
        self.reluIn = nn.ReLU()
        
        self.convI2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(5,5), stride=(2,2), padding=(6,6), dilation=(3,3))
        self.batNI2 = nn.BatchNorm2d(num_features=64)
        self.reluI2 = nn.ReLU()
        
        # Out CH = 32 !
        self.convI3 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=(5,5), stride=(2,2), padding=(6,6), dilation=(3,3))
        self.batNI3 = nn.BatchNorm2d(num_features=32)
        self.reluI3 = nn.ReLU()
        
        self.outMul = int(setImageSize / 8) 
            
        self.fc = nn.Sequential(
            nn.Linear(32 * self.outMul * self.outMul, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(1024, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(1024, 1024),
            nn.ReLU(inplace=True),
            #nn.Dropout(p=0.5),
            nn.Linear(1024, len(datasetClasses))) # number of classes
        
        self.logsmax = nn.LogSoftmax()

    def forward(self, x):
        # Convolutional layer 1
        #  Get the residual, match it to the output
        #plus01 = GetMatchingLayer(self.convIn.in_channels, self.convIn.out_channels)(x)
        convInResult = self.convIn(x)
        convInResult.register_hook(save_grad('convInGrad'))
        #  Add the residual before activation function
        x = self.reluIn(self.batNIn(convInResult)) #  + plus01
        
        # Convolutional layer 2
        #  Get the residual, match it to the output
        #plus02 = GetMatchingLayer(self.convI2.in_channels, self.convI2.out_channels)(x)
        convI2Result = self.convI2(x)
        convI2Result.register_hook(save_grad('convI2Grad'))
        #  Add the residual before activation function
        x = self.reluI2(self.batNI2(convI2Result)) # + plus02
        
        # Convolutional layer 3
        #  Get the residual, match it to the output
        #plus03 = GetMatchingLayer(self.convI3.in_channels, self.convI3.out_channels)(x)
        convI3Result = self.convI3(x)
        convI3Result.register_hook(save_grad('convI3Grad'))
        #  Add the residual before activation function
        x = self.reluI3(self.batNI3(convI3Result)) #  + plus03
        
        # Reshape the result for fully-connected layers
        x = x.view(-1, 32 * self.outMul * self.outMul)
        
        # Apply the result to fully-connected layers
        x = self.fc(x)
        
        # Finally apply the LogSoftMax for output
        x = self.logsmax(x)
        return x

# %% [markdown]
# #### DSMNLNet

# %%
class DSMNLNet(nn.Module):
    def __init__(self):
        super(DSMNLNet, self).__init__()
        self.convIn = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=(5,5), stride=(2,2), padding=(6,6), dilation=(3,3))
        self.batNIn = nn.BatchNorm2d(num_features=64)
        self.reluIn = nn.ReLU()
        
        self.convIA = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(1,1), stride=(1,1), padding=(0,0), dilation=(3,3))
        self.batNIA = nn.BatchNorm2d(num_features=64)
        self.reluIA = nn.ReLU()
                
        self.convI2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(5,5), stride=(2,2), padding=(6,6), dilation=(3,3))
        self.batNI2 = nn.BatchNorm2d(num_features=128)
        self.reluI2 = nn.ReLU()
        
        self.convIB = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=(1,1), stride=(1,1), padding=(0,0), dilation=(3,3))
        self.batNIB = nn.BatchNorm2d(num_features=128)
        self.reluIB = nn.ReLU()
        
        # Out CH = 32 !
        self.convI3 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=(5,5), stride=(2,2), padding=(6,6), dilation=(3,3))
        self.batNI3 = nn.BatchNorm2d(num_features=256)
        self.reluI3 = nn.ReLU()
        
        self.convIC = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=(1,1), stride=(1,1), padding=(0,0), dilation=(3,3))
        self.batNIC = nn.BatchNorm2d(num_features=256)
        self.reluIC = nn.ReLU()
        
        # Extended nonlinearity
        self.convI4 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=(1,1), stride=(1,1), padding=(0,0), dilation=(3,3))
        self.batNI4 = nn.BatchNorm2d(num_features=256)
        self.reluI4 = nn.ReLU()
        
        self.convI5 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=(1,1), stride=(1,1), padding=(0,0), dilation=(3,3))
        self.batNI5 = nn.BatchNorm2d(num_features=256)
        self.reluI5 = nn.ReLU()
        
        self.convI6 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=(1,1), stride=(1,1), padding=(0,0), dilation=(3,3))
        self.batNI6 = nn.BatchNorm2d(num_features=256)
        self.reluI6 = nn.ReLU()
            
        self.outMul = int(setImageSize / 8) 
            
        self.fc = nn.Sequential(
            nn.Linear(256 * self.outMul * self.outMul, len(datasetClasses)))
            #nn.ReLU(inplace=True),
            #nn.Dropout(p=0.5),
            #nn.Linear(4096, len(datasetClasses))) # number of classes
        
        self.logsmax = nn.LogSoftmax()

    def forward(self, x):
        # Convolutional layer 1
        #  Get the residual, match it to the output
        #plus01 = GetMatchingLayer(self.convIn.in_channels, self.convIn.out_channels)(x)
        convInResult = self.convIn(x)
        convInResult.register_hook(save_grad('convInGrad'))
        #  Add the residual before activation function
        x = self.reluIn(self.batNIn(convInResult)) #  + plus01
        
        x = self.reluIA(self.batNIA(self.convIA(x)))
        
        # Convolutional layer 2
        #  Get the residual, match it to the output
        #plus02 = GetMatchingLayer(self.convI2.in_channels, self.convI2.out_channels)(x)
        convI2Result = self.convI2(x)
        convI2Result.register_hook(save_grad('convI2Grad'))
        #  Add the residual before activation function
        x = self.reluI2(self.batNI2(convI2Result)) # + plus02
        
        x = self.reluIB(self.batNIB(self.convIB(x)))
        
        # Convolutional layer 3
        #  Get the residual, match it to the output
        #plus03 = GetMatchingLayer(self.convI3.in_channels, self.convI3.out_channels)(x)
        convI3Result = self.convI3(x)
        convI3Result.register_hook(save_grad('convI3Grad'))
        #  Add the residual before activation function
        x = self.reluI3(self.batNI3(convI3Result)) #  + plus03
        
        x = self.reluIC(self.batNIC(self.convIC(x)))
        
        x = self.reluI4(self.batNI4(self.convI4(x)))
        x = self.reluI5(self.batNI5(self.convI5(x)))
        x = self.reluI6(self.batNI6(self.convI6(x)))
        
        # Reshape the result for fully-connected layers
        x = x.view(-1, 256 * self.outMul * self.outMul)
        
        # Apply the result to fully-connected layers
        x = self.fc(x)
        
        # Finally apply the LogSoftMax for output
        x = self.logsmax(x)
        return x

# %% [markdown]
# Now let's initialize the network and use GPU if possible.

# %%
# Regular net
#net = Net()

# Net with batch normalization layers, added approx ~1m per 10 epochs
#net = NetBN()

# Net with BN + SELU + AlphaDropout
#net = NetBNSELU()

# A smaller Net with batch normalization
#net = NetSmallBN()

# BN with optimized params
#net = NetBNOptim()

# Net with dilated convolutions
#net = NetDilate()

# Net with dilated conv + 2 stride and removed pooling layers
#net = NetDilateStride()

# Net with dilation, stride, residuals and ELU as output
#net = DSPlusNet()

net = DSMNLNet()

#net = models.resnet50(pretrained=False)

if useGPU:
    net = net.cuda()

# %% [markdown]
# ### 2.5.2 Criterion and optimizer
# We successfully created our neural network. Now it is time to define a loss function and the optimizer.

# %%
# CrossEntropy already contains logsoftmax, use NLL
#criterion = nn.CrossEntropyLoss()
criterion = nn.NLLLoss()

# try 0.03 weight_decay
#optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=0.01, nesterov=True)
#optimizer = optim.Adam(net.parameters(), lr=0.0001, weight_decay=0.01)
#optimizer = optim.Adagrad(net.parameters(), lr=0.001, weight_decay=0.001)
optimizer = optim.RMSprop(net.parameters(), lr=0.0001, weight_decay=0.01)

lrScheduler = cnnUtils.StepLR(optimizer, step_size=10, gamma=0.5)

if useGPU:
    criterion = criterion.cuda()

# %% [markdown]
# ## 2.6 Training
#
# Mini-batch training method is preferred with PyTorch. It converges faster than the batch training method.
#
# *Example*
#
# *Mini-batch : With GTX 1070, 50 epochs train in 6m8s with 92.1% train and 93.9% test accuracy.*
#
# *Batch      : With GTX 1070, 80 epochs train in 7m32s with 98.5% train and 99.3% test accuracy.*

# %%
cnnUtils.TrainModelMiniBatch(net, criterion, optimizer, lrScheduler, datasetLoaders, datasetSizes, trainAccuracyTrain, trainAccuracyTest, trainLRValues, 
                    trainErrorTrain, trainErrorTest, num_epochs=30)
# Out:
# Epoch 0/29
# ----------
# LR: [0.0002]
# train Loss: 0.0232 Acc: 0.6154
# test Loss: 0.0103 Acc: 0.6661
#
# Epoch 1/29
# ----------
# LR: [0.0001]
# train Loss: 0.0076 Acc: 0.8156
# test Loss: 0.0114 Acc: 0.2115
#
# Epoch 2/29
# ----------
# LR: [0.0001]
# train Loss: 0.0085 Acc: 0.8077
# test Loss: 0.0343 Acc: 0.4548
#
# Epoch 3/29
# ----------
# LR: [0.0001]
# train Loss: 0.0046 Acc: 0.8780
# test Loss: 0.0683 Acc: 0.6726
#
# Epoch 4/29
# ----------
# LR: [0.0001]
# train Loss: 0.0040 Acc: 0.9085
# test Loss: 0.0762 Acc: 0.6801
#
# Epoch 5/29
# ----------
# LR: [0.0001]
# train Loss: 0.0037 Acc: 0.9164
# test Loss: 0.1950 Acc: 0.6866
#
# Epoch 6/29
# ----------
# LR: [0.0001]
# train Loss: 0.0032 Acc: 0.9231
# test Loss: 0.1058 Acc: 0.6996
#
# Epoch 7/29
# ----------
# LR: [0.0001]
# train Loss: 0.0022 Acc: 0.9350
# test Loss: 0.0691 Acc: 0.7180
#
# Epoch 8/29
# ----------
# LR: [0.0001]
# train Loss: 0.0023 Acc: 0.9483
# test Loss: 0.1392 Acc: 0.6941
#
# Epoch 9/29
# ----------
# LR: [0.0001]
# train Loss: 0.0019 Acc: 0.9536
# test Loss: 0.1269 Acc: 0.6941
#
# Epoch 10/29
# ----------
# LR: [0.0001]
# train Loss: 0.0015 Acc: 0.9655
# test Loss: 0.1339 Acc: 0.6952
#
# Epoch 11/29
# ----------
# LR: [5e-05]
# train Loss: 0.0018 Acc: 0.9576
# test Loss: 0.1662 Acc: 0.6946
#
# Epoch 12/29
# ----------
# LR: [5e-05]
# train Loss: 0.0017 Acc: 0.9642
# test Loss: 0.1359 Acc: 0.6920
#
# Epoch 13/29
# ----------
# LR: [5e-05]
# train Loss: 0.0013 Acc: 0.9788
# test Loss: 0.1515 Acc: 0.6985
#
# Epoch 14/29
# ----------
# LR: [5e-05]
# train Loss: 0.0015 Acc: 0.9642
# test Loss: 0.1584 Acc: 0.6975
#
# Epoch 15/29
# ----------
# LR: [5e-05]
# train Loss: 0.0018 Acc: 0.9562
# test Loss: 0.1635 Acc: 0.6972
#
# Epoch 16/29
# ----------
# LR: [5e-05]
# train Loss: 0.0016 Acc: 0.9536
# test Loss: 0.1627 Acc: 0.6957
#
# Epoch 17/29
# ----------
# LR: [5e-05]
# train Loss: 0.0011 Acc: 0.9761
# test Loss: 0.1544 Acc: 0.6967
#
# Epoch 18/29
# ----------
# LR: [5e-05]
# train Loss: 0.0013 Acc: 0.9682
# test Loss: 0.1565 Acc: 0.6980
#
# Epoch 19/29
# ----------
# LR: [5e-05]
# train Loss: 0.0011 Acc: 0.9775
# test Loss: 0.1463 Acc: 0.7136
#
# Epoch 20/29
# ----------
# LR: [5e-05]
# train Loss: 0.0009 Acc: 0.9828
# test Loss: 0.1599 Acc: 0.6978
#
# Epoch 21/29
# ----------
# LR: [2.5e-05]
# train Loss: 0.0008 Acc: 0.9814
# test Loss: 0.2024 Acc: 0.6970
#
# Epoch 22/29
# ----------
# LR: [2.5e-05]
# train Loss: 0.0008 Acc: 0.9814
# test Loss: 0.1693 Acc: 0.6983
#
# Epoch 23/29
# ----------
# LR: [2.5e-05]
# train Loss: 0.0008 Acc: 0.9867
# test Loss: 0.1673 Acc: 0.6983
#
# Epoch 24/29
# ----------
# LR: [2.5e-05]
# train Loss: 0.0010 Acc: 0.9788
# test Loss: 0.1687 Acc: 0.6991
#
# Epoch 25/29
# ----------
# LR: [2.5e-05]
# train Loss: 0.0007 Acc: 0.9841
# test Loss: 0.1704 Acc: 0.6978
#
# Epoch 26/29
# ----------
# LR: [2.5e-05]
# train Loss: 0.0009 Acc: 0.9775
# test Loss: 0.1608 Acc: 0.6975
#
# Epoch 27/29
# ----------
# LR: [2.5e-05]
# train Loss: 0.0008 Acc: 0.9828
# test Loss: 0.1592 Acc: 0.6985
#
# Epoch 28/29
# ----------
# LR: [2.5e-05]
# train Loss: 0.0007 Acc: 0.9841
# test Loss: 0.1692 Acc: 0.6991
#
# Epoch 29/29
# ----------
# LR: [2.5e-05]
# train Loss: 0.0008 Acc: 0.9854
# test Loss: 0.1523 Acc: 0.6991
#
# Training complete in 12m 33s
# Best val Acc: 0.718035
# DSMNLNet (
#   (convIn): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(6, 6), dilation=(3, 3))
#   (batNIn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (reluIn): ReLU ()
#   (convIA): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), dilation=(3, 3))
#   (batNIA): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (reluIA): ReLU ()
#   (convI2): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(6, 6), dilation=(3, 3))
#   (batNI2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (reluI2): ReLU ()
#   (convIB): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), dilation=(3, 3))
#   (batNIB): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (reluIB): ReLU ()
#   (convI3): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(6, 6), dilation=(3, 3))
#   (batNI3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (reluI3): ReLU ()
#   (convIC): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), dilation=(3, 3))
#   (batNIC): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (reluIC): ReLU ()
#   (convI4): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), dilation=(3, 3))
#   (batNI4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (reluI4): ReLU ()
#   (convI5): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), dilation=(3, 3))
#   (batNI5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (reluI5): ReLU ()
#   (convI6): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), dilation=(3, 3))
#   (batNI6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (reluI6): ReLU ()
#   (fc): Sequential (
#     (0): Linear (65536 -> 2)
#   )
#   (logsmax): LogSoftmax ()
# )

# %%
print(net)
gradIn = grads['convInGrad']
gradI2 = grads['convI2Grad']
gradI3 = grads['convI3Grad']


cnnUtils.PlotActivationMaps(gradIn)
#cnnUtils.PlotActivationMaps(gradI2)
#cnnUtils.PlotActivationMaps(gradI3)
# Out:
# DSPlusNet (
#   (convIn): Conv2d(3, 32, kernel_size=(5, 5), stride=(2, 2), padding=(6, 6), dilation=(3, 3))
#   (batNIn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True)
#   (reluIn): ReLU ()
#   (convI2): Conv2d(32, 64, kernel_size=(5, 5), stride=(2, 2), padding=(6, 6), dilation=(3, 3))
#   (batNI2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (reluI2): ReLU ()
#   (convI3): Conv2d(64, 32, kernel_size=(5, 5), stride=(2, 2), padding=(6, 6), dilation=(3, 3))
#   (batNI3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True)
#   (reluI3): ReLU ()
#   (fc): Sequential (
#     (0): Linear (8192 -> 1024)
#     (1): ReLU (inplace)
#     (2): Dropout (p = 0.5)
#     (3): Linear (1024 -> 1024)
#     (4): ReLU (inplace)
#     (5): Dropout (p = 0.5)
#     (6): Linear (1024 -> 1024)
#     (7): ReLU (inplace)
#     (8): Linear (1024 -> 2)
#   )
#   (logsmax): LogSoftmax ()
# )

# %% [markdown]
# ### 2.6.3 Visualization of the progress

# %%
cnnUtils.PlotArrays([trainErrorTrain, trainErrorTest], ['Training', 'Test'], xlabel='Epoch', ylabel='Loss', title='Loss over epoch')
cnnUtils.PlotArrays([trainLRValues], ['Learning rate'], xlabel='Epoch', ylabel='Learning rate', title='Learning rate decrease')
cnnUtils.PlotArrays([trainAccuracyTrain, trainAccuracyTest], ['Training accuracy', 'Test accuracy'], xlabel='Epoch', ylabel='Accuracy', title='Accuracy increase over epoch')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d18894c6-83b0-497d-a8ef-9e8e487151d6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d18894c6-83b0-497d-a8ef-9e8e487151d6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d18894c6-83b0-497d-a8ef-9e8e487151d6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd18894c6-83b0-497d-a8ef-9e8e487151d6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d9abc9f5-66e4-4a0e-872c-7eedfb29d416":{"roots":{"references":[{"attributes":{"plot":{"id":"e4cf1e3c-c4bb-49b5-b65a-f0e9cee04fa6","subtype":"Figure","type":"Plot"}},"id":"fb01e527-45a7-4d65-a377-b36fa956c4be","type":"ResetTool"},{"attributes":{"plot":{"id":"e4cf1e3c-c4bb-49b5-b65a-f0e9cee04fa6","subtype":"Figure","type":"Plot"}},"id":"294ea59c-ceca-4834-bb5a-164f2e8bca28","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"e4cf1e3c-c4bb-49b5-b65a-f0e9cee04fa6","subtype":"Figure","type":"Plot"},"ticker":{"id":"3f15f55d-e5db-45b4-9b13-d805e9b26b2b","type":"BasicTicker"}},"id":"6067cce1-cd19-4f47-8742-fe9b6dd18c50","type":"Grid"},{"attributes":{},"id":"21749372-ab27-4453-9ced-3ad7fc664471","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"82ed5a0c-7a7c-4b12-bc4a-87301c11c264","type":"Line"},{"attributes":{"overlay":{"id":"07136f61-08bd-43c2-bf6e-e407015cf2de","type":"BoxAnnotation"},"plot":{"id":"e4cf1e3c-c4bb-49b5-b65a-f0e9cee04fa6","subtype":"Figure","type":"Plot"}},"id":"e6c81bfe-8b95-4d8d-beeb-eb73c6ed6862","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"bc9b9fae-1c63-4b29-b1bc-49b66174988e","type":"ColumnDataSource"},"glyph":{"id":"e1458905-bc33-469f-80b1-4571dc3749d3","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"82ed5a0c-7a7c-4b12-bc4a-87301c11c264","type":"Line"},"selection_glyph":null},"id":"f9b80098-a35b-433a-9325-df3ebc448a38","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f436e6e1-f41c-4b9d-abbe-c82c04454151","type":"Circle"},{"attributes":{"label":{"value":"Test"},"renderers":[{"id":"aa7aa8e2-238f-400a-89df-7fc96fa3db3b","type":"GlyphRenderer"},{"id":"f9b80098-a35b-433a-9325-df3ebc448a38","type":"GlyphRenderer"}]},"id":"90278e1a-23ae-4c9f-8b1c-8ef82b463848","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"","dtype":"float64","shape":[30]},"y":[0.01794381927827309,0.002485020343085815,0.0025807408028003073,0.0016214980790762118,0.0013007196024633371,0.0010636443178359647,0.0013886133198989482,0.0009520775477947859,0.0008046498919889054,0.0010866917192995232,0.0006061468275871612,0.0004356878276034913,0.00029614100983707276,0.00044589610251570885,0.00038720863014064355,0.00034246618417276947,0.00021774158257230206,0.0003733093311777956,0.0003366924807508365,0.00027368992038407123,0.0002370880989590042,0.00023034171865813296,9.70648362027081e-05,0.00013844817827408763,6.785759589923867e-05,9.053134277897741e-05,5.616184659993933e-05,6.140714072170285e-05,6.307482618136968e-05,8.094398581499446e-05]}},"id":"56efe7e0-5210-407f-9a44-e8d3b63724f4","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"fa344b45-48a3-4045-9b73-c2ef0f1f98b2","type":"ColumnDataSource"},"glyph":{"id":"3d30dd31-1979-47c0-a24c-8d6a607f309d","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f436e6e1-f41c-4b9d-abbe-c82c04454151","type":"Circle"},"selection_glyph":null},"id":"11353b74-f580-4055-8901-dd99f09b907a","type":"GlyphRenderer"},{"attributes":{},"id":"29410f23-210b-4dda-95f7-0df3be1bf980","type":"ToolEvents"},{"attributes":{"fill_color":{"value":"#3288bd"},"line_color":{"value":"#3288bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3d30dd31-1979-47c0-a24c-8d6a607f309d","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAAAAAAAAD ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="69e16f9f-ab21-4f7c-a2cc-589a08a57fd8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("69e16f9f-ab21-4f7c-a2cc-589a08a57fd8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("69e16f9f-ab21-4f7c-a2cc-589a08a57fd8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '69e16f9f-ab21-4f7c-a2cc-589a08a57fd8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d3730fa4-52a0-4f6e-af40-34058e3089de":{"roots":{"references":[{"attributes":{"data_source":{"id":"074ecc54-0564-4704-93e5-980fd6d7b947","type":"ColumnDataSource"},"glyph":{"id":"daf39f11-5bff-4459-8a70-06a3d5d0a92b","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8b614ef5-9277-4e3e-bef4-105a285867b2","type":"Line"},"selection_glyph":null},"id":"bf388a47-8a2e-4a35-8cf9-928c103a877d","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8b614ef5-9277-4e3e-bef4-105a285867b2","type":"Line"},{"attributes":{},"id":"d3af6ab8-0f8e-44af-abc9-dca98b25a615","type":"ToolEvents"},{"attributes":{"below":[{"id":"07cddfc2-b056-413f-a332-9e0fb7560a58","type":"LinearAxis"}],"left":[{"id":"916133ac-2232-415e-a525-d0aa0051e4cd","type":"LinearAxis"}],"renderers":[{"id":"07cddfc2-b056-413f-a332-9e0fb7560a58","type":"LinearAxis"},{"id":"4d0d736d-698f-4038-8c4c-8920c872f305","type":"Grid"},{"id":"916133ac-2232-415e-a525-d0aa0051e4cd","type":"LinearAxis"},{"id":"360972a8-5937-4127-9537-b62ea3d292e2","type":"Grid"},{"id":"187b3198-f3a2-4fc6-b3ea-0473400e8502","type":"BoxAnnotation"},{"id":"187b1186-1f84-4752-a6eb-0b5412f19ab4","type":"Legend"},{"id":"e590cf22-ff7a-4cf8-8c48-12250d3494c0","type":"GlyphRenderer"},{"id":"bf388a47-8a2e-4a35-8cf9-928c103a877d","type":"GlyphRenderer"}],"title":{"id":"7a1a8e3b-4893-48b0-9218-e3a51fe8103e","type":"Title"},"tool_events":{"id":"d3af6ab8-0f8e-44af-abc9-dca98b25a615","type":"ToolEvents"},"toolbar":{"id":"494ebd8f-652e-48b4-ade4-ca0f12be8f6a","type":"Toolbar"},"x_range":{"id":"3bcbc4a6-ecfa-4ba7-9710-3138ba77b9ae","type":"DataRange1d"},"x_scale":{"id":"9806f299-aa6d-48b5-a902-151428f1d379","type":"LinearScale"},"y_range":{"id":"60ffa405-f57e-4de5-adfb-aad158841bfe","type":"DataRange1d"},"y_scale":{"id":"28eb51a8-5bbe-4bb7-ad8b-6fb6c7b4f5db","type":"LinearScale"}},"id":"b1d4000e-f036-4220-82d3-fe34a9f7bd2d","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"#3288bd"},"line_color":{"value":"#3288bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"96361df7-5f4c-4292-b1c4-6302000b5cb2","type":"Circle"},{"attributes":{"callback":null},"id":"3bcbc4a6-ecfa-4ba7-9710-3138ba77b9ae","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"","dtype":"float64","shape":[30]},"y":[[0.0002],[0.0001],[0.0001],[0.0001],[0.0001],[0.0001],[0.0001],[0.0001],[0.0001],[0.0001],[0.0001],[5e-05],[5e-05],[5e-05],[5e-05],[5e-05],[5e-05],[5e-05],[5e-05],[5e-05],[5e-05],[2.5e-05],[2.5e-05],[2.5e-05],[2.5e-05],[2.5e-05],[2.5e-05],[2.5e-05],[2.5e-05],[2.5e-05]]}},"id":"074ecc54-0564-4704-93e5-980fd6d7b947","type":"ColumnDataSource"},{"attributes":{},"id":"47bf95c9-d512-4fcc-b4fa-0c66b7822ce3","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#3288bd"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"daf39f11-5bff-4459-8a70-06a3d5d0a92b","type":"Line"},{"attributes":{"data_source":{"id":"0ad8e98e-d5fc-4e68-b970-a318b4e82d65","type":"ColumnDataSource"},"glyph":{"id":"96361df7-5f4c-4292-b1c4-6302000b5cb2","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bbddebce-3f52-40e8-98cc-edb0809edf80","type":"Circle"},"selection_glyph":null},"id":"e590cf22-ff7a-4cf8-8c48-12250d3494c0","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"b1d4000e-f036-4220-82d3-fe34a9f7bd2d","subtype":"Figure","type":"Plot"}},"id":"12c2718b-5175-4cc6-a0f4-508a6e8a4e97","type":"SaveTool"},{"attributes":{"plot":{"id":"b1d4000e-f036-4220-82d3-fe34a9f7bd2d","s ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6094e1f6-d279-4256-b511-250987e23951"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6094e1f6-d279-4256-b511-250987e23951");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6094e1f6-d279-4256-b511-250987e23951");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6094e1f6-d279-4256-b511-250987e23951' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d5d64ee4-e6a9-4b2b-8531-193f26ec3742":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"","dtype":"float64","shape":[30]},"y":[0.6660602910602911,0.6660602910602911,0.6746361746361746,0.7902806652806653,0.7876819126819127,0.8651247401247402,0.8417359667359667,0.8659043659043659,0.7593555093555093,0.8573284823284824,0.860966735966736,0.7884615384615384,0.8097713097713097,0.8588877338877339,0.8586278586278586,0.854989604989605,0.8292619542619543,0.8682432432432432,0.8607068607068608,0.8575883575883576,0.8586278586278586,0.8557692307692307,0.8586278586278586,0.863045738045738,0.8607068607068608,0.867983367983368,0.860966735966736,0.8601871101871101,0.8599272349272349,0.8396569646569647]}},"id":"90c96703-8bcf-4246-b34c-08c3b54bf944","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"8db775b4-2f90-48be-a8e4-b0a241606d57","subtype":"Figure","type":"Plot"},"ticker":{"id":"18f51948-17e1-4d86-b5fb-5b3ba19e8849","type":"BasicTicker"}},"id":"379af1bc-99b3-46c6-a285-9c4a1ef44cc7","type":"Grid"},{"attributes":{"label":{"value":"Test accuracy"},"renderers":[{"id":"d66110fe-f68d-4af1-b7ff-cab18cd8513d","type":"GlyphRenderer"},{"id":"93a095f8-f64c-40b2-a691-e749759e5356","type":"GlyphRenderer"}]},"id":"58c2e593-846f-416d-a17b-ad17be58f197","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"dc914e1b-cb03-4165-afa5-4966cdb350f6","type":"Line"},{"attributes":{"data_source":{"id":"90c96703-8bcf-4246-b34c-08c3b54bf944","type":"ColumnDataSource"},"glyph":{"id":"8e3f85c1-aabb-4067-a126-588ea19617db","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5f5dec33-1709-4a02-b4e9-a4f4efe7e2bc","type":"Circle"},"selection_glyph":null},"id":"d66110fe-f68d-4af1-b7ff-cab18cd8513d","type":"GlyphRenderer"},{"attributes":{"axis_label":"Accuracy","formatter":{"id":"bc121a9a-4e78-4d1e-8d30-bceba7d185c2","type":"BasicTickFormatter"},"plot":{"id":"8db775b4-2f90-48be-a8e4-b0a241606d57","subtype":"Figure","type":"Plot"},"ticker":{"id":"a95e0f10-b060-4efd-bba1-7c6f822bd352","type":"BasicTicker"}},"id":"1b92b817-1adb-4d6a-a9a5-b4cb5a76a7b1","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#3288bd"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"efc6c093-6241-47bc-95b1-9c1f713ee31b","type":"Line"},{"attributes":{"data_source":{"id":"94c42ba6-afeb-4b7c-a981-c52d8c4945c6","type":"ColumnDataSource"},"glyph":{"id":"efc6c093-6241-47bc-95b1-9c1f713ee31b","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"dc914e1b-cb03-4165-afa5-4966cdb350f6","type":"Line"},"selection_glyph":null},"id":"5dce00e4-7135-4ef5-95f4-0567a99e7422","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"","dtype":"float64","shape":[30]},"y":[0.7413793103448276,0.9376657824933687,0.9389920424403183,0.96684350132626,0.9681697612732095,0.9761273209549072,0.9628647214854111,0.980106100795756,0.9787798408488063,0.9761273209549072,0.986737400530504,0.9920424403183024,0.9973474801061007,0.9893899204244032,0.9893899204244032,0.9946949602122016,0.9960212201591512,0.9920424403183024,0.9907161803713528,0.9960212201591512,0.9960212201591512,0. ...

# %% [markdown]
# ## 2.7 Visualization of the weights
#
# This section is still in development.

# %%
cnnUtils.plotNNFilter(net.convIn.weight.cpu().data.numpy())
# Out:
# (64, 3, 5, 5)

# %% [markdown]
# ## 2.8 Evaluating network accuracy
# Let's calculate the accuracy on the training set.

# %%
def DetermineAccuracy(phase, datasetLoaders):
    correct = 0
    total = 0
    for data in datasetLoaders[phase]:
        # Inputs
        inputs, labels = data
        if torch.cuda.is_available():
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        outputs = net(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.data).sum()
    return correct, total


correct, total = DetermineAccuracy('train', datasetLoaders)
print('Accuracy of the network for training set is {}%'.format(100 * correct / total))
# Out:
# Accuracy of the network for training set is 100.0%

# %% [markdown]
# Now time to see the accuracy of the test set.

# %%
correct, total = DetermineAccuracy('test', datasetLoaders)
print('Accuracy of the network for test set is {}%'.format(100 * correct / total))
# Out:
# Accuracy of the network for test set is 83.96569646569647%

# %% [markdown]
# Let's see individual class performance along with the confusion matrix.

# %%
datasetLen = len(datasetClasses)
classCorrect = list(0. for i in range(datasetLen))
classTotal = list(0. for i in range(datasetLen))
confusion = torch.zeros(datasetLen, datasetLen)

for i, data in enumerate(testLoader):
    inputs, labels = data
    if useGPU:
        inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
    else:
        inputs, labels = Variable(inputs), Variable(labels)
    
    outputs = net(inputs)
    _, predicted = torch.max(outputs.data, 1)

    classTotal[labels.data.cpu().numpy()[0]] += 1
    confusion[labels.data.cpu().numpy()[0]][predicted[0][0]] += 1
    
    if labels.data.cpu().numpy()[0] == predicted.cpu().numpy()[0][0]:
        classCorrect[labels.data.cpu().numpy()[0]] += 1
    #else: # Display failure cases
        #out = torchvision.utils.make_grid(inputs.data.cpu())
        #cnnUtils.ImShow(out, mean=setMean, std=setStd, title=datasetClasses[labels.data.cpu()[0]])

for i, cls in enumerate(classCorrect):
    print('Class ' + datasetClasses[i] + ' total: ' + str(classTotal[i]) + ' correct: ' + str(classCorrect[i]) + ' success rate is ' + str(100 * classCorrect[i] / classTotal[i])) 

    
# Normalize confusion matrix
for i in range(datasetLen):
    confusion[i] = confusion[i] / confusion[i].sum()
    
# Plot confusion matrix
fig = plt.figure()
ax = fig.add_subplot(111)
#cax = ax.matshow(confusion.numpy())
plt.imshow(confusion.numpy(), interpolation='nearest', cmap=plt.cm.Greens)
plt.colorbar()

ax.set_xticklabels([''] + datasetClasses, rotation=90)
ax.set_yticklabels([''] + datasetClasses)
thresh = confusion.max() / 2.0

for i in range(confusion.numpy().shape[0]):
    for j in range(confusion.numpy().shape[1]):
        plt.text(j, i, np.around(confusion[i,j], 3), horizontalalignment="center", color="white" if confusion[i, j] > thresh else "black")

# Force label at every tick
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

plt.show()
# Out:
# Class defect total: 2563.0 correct: 2556.0 success rate is 99.72688255950058
# Class nonDefect total: 1285.0 correct: 134.0 success rate is 10.428015564202335

# %% [markdown]
# Results are looking good, let's save the model for future use.

# %%
torch.save(net, 'EBA5CNN.net')
# Out:
# g:\Anaconda3\envs\PyTorchEnv\lib\site-packages\torch\serialization.py:147: UserWarning: Couldn't retrieve source code for container of type NetBN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
netb = torch.load('EBACNN.net')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7bb9560d656> in <module>()
# ----> 1 netb = torch.load('EBACNN.net')
#
# NameError: name 'torch' is not defined

# %% [markdown]
# #### Forward-pass benchmark

# %%
input, label = next(iter(datasetLoaders['train']))
input, label = Variable(input.cuda()), Variable(label.cuda())

startT = time.perf_counter()
outputs = net(input)
endT = time.perf_counter()
_, predicted = torch.max(outputs.data, 1)
    
print(str((endT-startT) * 1000)  + ' ms')
# Out:
# 3.894154591885357 ms
